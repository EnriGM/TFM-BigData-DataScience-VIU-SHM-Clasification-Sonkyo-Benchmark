# %% [markdown]
# K neightbours classifier time

# %%
import numpy as np

x = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality\x_for_ml.npy")
y = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality\y_for_ml.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score
from datetime import datetime

print(datetime.now())

n_iter_search = 10

param_dist = {"n_neighbors": list(range(40, 100)),
              "weights": ["uniform", "distance"],
              "algorithm": ["kd_tree"],
              "p": [1]
              }

clf = KNeighborsClassifier()
print("start random search")
random_search = RandomizedSearchCV(
    clf, param_distributions=param_dist, n_iter=n_iter_search,
    random_state=SEED, verbose=3)

random_search.fit(X_train, y_train)
print(random_search.best_params_)
model = random_search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
print(datetime.now())
# Out:
# 2026-01-22 19:52:22.006997
# start random search
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.319 total time=  40.3s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.325 total time=  40.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.322 total time=  39.4s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.320 total time=  38.8s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.320 total time=  38.1s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.320 total time=  37.9s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.326 total time=  37.4s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.322 total time=  37.4s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.321 total time=  36.9s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.321 total time=  37.2s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.318 total time=  37.5s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.324 total time=  35.5s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.318 total time=  33.5s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.317 total time=  33.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.318 total time=  33.3s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.321 total time=  38.6s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.326 total time=  38.5s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.323 total time=  38.3s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.322 total time=  37.8s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.322 total time=  38.3s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.318 total time=  36.7s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.326 total time=  36.3s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.321 total time=  36.2s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.319 total time=  35.7s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.319 total time=  36.3s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.319 total time=  40.5s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.325 total time=  40.3s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.323 total time=  40.2s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.321 total time=  39.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.320 total time=  39.2s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.320 total time=  39.6s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.326 total time=  39.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.323 total time=  39.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.321 total time=  38.5s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.321 total time=  39.3s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.319 total time=  33.9s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.325 total time=  33.5s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.319 total time=  33.2s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.317 total time=  33.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.318 total time=  33.3s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.319 total time=  37.2s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.325 total time=  36.9s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.322 total time=  36.8s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.321 total time=  36.4s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.320 total time=  36.7s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.321 total time=  42.3s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.325 total time=  42.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.324 total time=  42.4s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.322 total time=  41.5s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.322 total time=  41.8s
# {'weights': 'distance', 'p': 1, 'n_neighbors': 93, 'algorithm': 'kd_tree'}
# precision 0.32819835680751175
# 2026-01-22 20:24:55.028391

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score
from sklearn.model_selection import GridSearchCV

param_dist = {"n_neighbors": list(range(76, 80)),
              "weights": ["distance"],
              "algorithm": ["kd_tree"],
              "p": [1]
              }

clf = KNeighborsClassifier()
print("start random search")
search = GridSearchCV(clf, param_grid=param_dist, verbose=3)

search.fit(X_train, y_train)
print(search.best_params_)
model = search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
# Out:
# start random search
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.320 total time=  39.5s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.326 total time=  39.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.323 total time=  38.9s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.321 total time=  38.6s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.321 total time=  40.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=77, p=1, weights=distance;, score=0.321 total time=  40.5s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=77, p=1, weights=distance;, score=0.326 total time=  40.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=77, p=1, weights=distance;, score=0.323 total time=  40.0s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=77, p=1, weights=distance;, score=0.322 total time=  39.5s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=77, p=1, weights=distance;, score=0.321 total time=  40.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=78, p=1, weights=distance;, score=0.321 total time=  40.8s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=78, p=1, weights=distance;, score=0.327 total time=  40.5s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=78, p=1, weights=distance;, score=0.323 total time=  40.3s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=78, p=1, weights=distance;, score=0.322 total time=  39.7s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=78, p=1, weights=distance;, score=0.322 total time=  40.1s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=79, p=1, weights=distance;, score=0.321 total time=  40.8s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=79, p=1, weights=distance;, score=0.326 total time=  40.5s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=79, p=1, weights=distance;, score=0.323 total time=  40.5s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=79, p=1, weights=distance;, score=0.323 total time=  40.1s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=79, p=1, weights=distance;, score=0.321 total time=  40.4s
# {'algorithm': 'kd_tree', 'n_neighbors': 79, 'p': 1, 'weights': 'distance'}
# precision 0.3279468477531858

# %%
import pickle 

with open(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\time_all_std_force_quality\KNC_time.pickle', 'wb') as f:

    pickle.dump(model, f)

# %% [markdown]
# K neightbours classifier freq

# %%
import numpy as np

x = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality_freq\x_for_ml.npy")
y = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality_freq\y_for_ml.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score
from datetime import datetime

print(datetime.now())

n_iter_search = 10

param_dist = {"n_neighbors": list(range(40, 100)),
              "weights": ["uniform", "distance"],
              "algorithm": ["kd_tree"],
              "p": [1]
              }

clf = KNeighborsClassifier()
print("start random search")
random_search = RandomizedSearchCV(
    clf, param_distributions=param_dist, n_iter=n_iter_search,
    random_state=SEED, verbose=3)

random_search.fit(X_train, y_train)
print(random_search.best_params_)
model = random_search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
print(datetime.now())
# Out:
# 2026-01-22 20:39:18.118055
# start random search
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.410 total time=   7.8s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.412 total time=   7.8s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.406 total time=   7.8s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.409 total time=   7.8s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=62, p=1, weights=uniform;, score=0.409 total time=   7.7s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.420 total time=   6.8s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.423 total time=   6.8s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.419 total time=   6.8s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.422 total time=   6.9s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=63, p=1, weights=distance;, score=0.420 total time=   6.8s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.410 total time=   6.8s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.412 total time=   6.8s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.408 total time=   6.8s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.412 total time=   6.8s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=42, p=1, weights=uniform;, score=0.410 total time=   6.8s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.421 total time=   7.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.423 total time=   7.0s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.417 total time=   7.1s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.420 total time=   7.0s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=67, p=1, weights=distance;, score=0.419 total time=   7.0s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.409 total time=   7.4s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.411 total time=   7.4s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.407 total time=   7.4s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.411 total time=   7.4s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=uniform;, score=0.408 total time=   7.4s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.410 total time=   8.3s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.410 total time=   8.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.405 total time=   8.2s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.408 total time=   8.3s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=72, p=1, weights=uniform;, score=0.408 total time=   8.2s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.420 total time=   7.4s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.421 total time=   7.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.416 total time=   7.3s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.419 total time=   7.2s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=76, p=1, weights=distance;, score=0.420 total time=   7.2s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.409 total time=   6.8s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.413 total time=   6.8s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.408 total time=   6.8s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.411 total time=   6.8s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=45, p=1, weights=uniform;, score=0.410 total time=   6.8s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.410 total time=   7.5s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.413 total time=   7.5s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.406 total time=   7.5s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.410 total time=   7.5s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=60, p=1, weights=uniform;, score=0.409 total time=   7.5s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.418 total time=   8.0s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.419 total time=   7.9s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.415 total time=   7.9s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.417 total time=   7.9s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=93, p=1, weights=distance;, score=0.418 total time=   7.9s
# {'weights': 'distance', 'p': 1, 'n_neighbors': 63, 'algorithm': 'kd_tree'}
# precision 0.43091884641180417
# 2026-01-22 20:45:40.758971

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score
from sklearn.model_selection import GridSearchCV

param_dist = {"n_neighbors": list(range(50, 65)),
              "weights": ["distance"],
              "algorithm": ["kd_tree"],
              "p": [1]
              }

clf = KNeighborsClassifier()
print("start random search")
search = GridSearchCV(clf, param_grid=param_dist, verbose=3)

search.fit(X_train, y_train)
print(search.best_params_)
model = search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
# Out:
# start random search
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END algorithm=kd_tree, n_neighbors=50, p=1, weights=distance;, score=0.422 total time=   6.1s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=50, p=1, weights=distance;, score=0.424 total time=   6.1s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=50, p=1, weights=distance;, score=0.420 total time=   6.1s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=50, p=1, weights=distance;, score=0.423 total time=   6.1s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=50, p=1, weights=distance;, score=0.421 total time=   6.1s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=51, p=1, weights=distance;, score=0.423 total time=   6.2s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=51, p=1, weights=distance;, score=0.425 total time=   6.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=51, p=1, weights=distance;, score=0.419 total time=   6.1s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=51, p=1, weights=distance;, score=0.424 total time=   6.1s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=51, p=1, weights=distance;, score=0.421 total time=   6.1s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=52, p=1, weights=distance;, score=0.422 total time=   6.2s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=52, p=1, weights=distance;, score=0.425 total time=   6.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=52, p=1, weights=distance;, score=0.419 total time=   6.2s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=52, p=1, weights=distance;, score=0.423 total time=   6.2s
# [CV 5/5] END algorithm=kd_tree, n_neighbors=52, p=1, weights=distance;, score=0.421 total time=   6.2s
# [CV 1/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=distance;, score=0.422 total time=   6.3s
# [CV 2/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=distance;, score=0.425 total time=   6.2s
# [CV 3/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights=distance;, score=0.419 total time=   6.2s
# [CV 4/5] END algorithm=kd_tree, n_neighbors=53, p=1, weights