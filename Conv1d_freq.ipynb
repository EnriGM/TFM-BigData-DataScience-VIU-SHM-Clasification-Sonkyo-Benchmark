# %%
import numpy as np

x = np.load(
    r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\freq_data_1_sec_force_quality_plus_t\x_for_ltsm.npy")
y = np.load(
    r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\freq_data_1_sec_force_quality_plus_t\y_for_ltsm.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

signal_x_train = x_train[:, :-1]
signal_x_test = x_test[:, :-1]
temp_x_train = x_train[:, -1]
temp_x_test = x_test[:, -1]

# %%
import tensorflow as tf
from tensorflow import keras


time_input = keras.layers.Input(shape=(129, 1))
temp_input = keras.layers.Input(shape=(1,))

conv_1 = keras.layers.Conv1D(filters=32, kernel_size=32, strides=2, activation='relu')(time_input)

conv_3 = keras.layers.Conv1D(filters=64, kernel_size=16, strides=2, activation='relu')(conv_1)

conv_4 = keras.layers.Conv1D(filters=128, kernel_size=8, strides=2, activation='relu')(conv_3)

flat = keras.layers.Flatten()(conv_4)

dense0 = keras.layers.Dense(1, activation="relu")(temp_input)

merged = keras.layers.Concatenate(axis=1)([flat, dense0])

dense_1 = keras.layers.Dense(128, activation='relu')(merged)
dense_2 = keras.layers.Dense(64, activation='relu')(dense_1)
output = keras.layers.Dense(13, activation='softmax')(dense_2)

model = keras.models.Model(inputs=[time_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 129, 1)]     0           []
#
#  conv1d (Conv1D)                (None, 49, 32)       1056        ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 17, 64)       32832       ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 5, 128)       65664       ['conv1d_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  flatten (Flatten)              (None, 640)          0           ['conv1d_2[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 641)          0           ['flatten[0][0]',
#                                                                   'dense[0][0]']
#
#  dense_1 (Dense)                (None, 128)          82176       ['concatenate[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 13)           845         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 190,831
# Trainable params: 190,831
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="acc")
    ],
)

# %%
batch_size = 128
num_epochs = 500

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
# Fit the model.

history = model.fit(
    x=[signal_x_train, temp_x_train],
    y=y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=0.1,
    callbacks=[early_stopping],
    verbose=2,
)
# Out:
# Epoch 1/500
# 1342/1342 - 8s - loss: 0.5634 - acc: 0.8111 - val_loss: 0.2512 - val_acc: 0.9128 - 8s/epoch - 6ms/step
# Epoch 2/500
# 1342/1342 - 6s - loss: 0.2028 - acc: 0.9272 - val_loss: 0.1633 - val_acc: 0.9419 - 6s/epoch - 4ms/step
# Epoch 3/500
# 1342/1342 - 6s - loss: 0.1471 - acc: 0.9474 - val_loss: 0.1392 - val_acc: 0.9497 - 6s/epoch - 4ms/step
# Epoch 4/500
# 1342/1342 - 6s - loss: 0.1217 - acc: 0.9567 - val_loss: 0.1059 - val_acc: 0.9634 - 6s/epoch - 4ms/step
# Epoch 5/500
# 1342/1342 - 6s - loss: 0.1038 - acc: 0.9628 - val_loss: 0.0950 - val_acc: 0.9666 - 6s/epoch - 4ms/step
# Epoch 6/500
# 1342/1342 - 6s - loss: 0.0922 - acc: 0.9670 - val_loss: 0.0999 - val_acc: 0.9637 - 6s/epoch - 4ms/step
# Epoch 7/500
# 1342/1342 - 6s - loss: 0.0832 - acc: 0.9702 - val_loss: 0.0748 - val_acc: 0.9742 - 6s/epoch - 4ms/step
# Epoch 8/500
# 1342/1342 - 6s - loss: 0.0757 - acc: 0.9730 - val_loss: 0.0707 - val_acc: 0.9739 - 6s/epoch - 4ms/step
# Epoch 9/500
# 1342/1342 - 6s - loss: 0.0692 - acc: 0.9754 - val_loss: 0.0718 - val_acc: 0.9744 - 6s/epoch - 4ms/step
# Epoch 30/500
# 1342/1342 - 6s - loss: 0.0236 - acc: 0.9916 - val_loss: 0.0405 - val_acc: 0.9856 - 6s/epoch - 4ms/step
# Epoch 31/500
# 1342/1342 - 6s - loss: 0.0216 - acc: 0.9925 - val_loss: 0.0478 - val_acc: 0.9824 - 6s/epoch - 4ms/step
# Epoch 32/500
# 1342/1342 - 6s - loss: 0.0214 - acc: 0.9925 - val_loss: 0.0383 - val_acc: 0.9868 - 6s/epoch - 4ms/step
# Epoch 33/500
# 1342/1342 - 6s - loss: 0.0203 - acc: 0.9928 - val_loss: 0.0374 - val_acc: 0.9862 - 6s/epoch - 4ms/step
# Epoch 34/500
# 1342/1342 - 6s - loss: 0.0200 - acc: 0.9930 - val_loss: 0.0443 - val_acc: 0.9846 - 6s/epoch - 4ms/step
# Epoch 35/500
# 1342/1342 - 6s - loss: 0.0184 - acc: 0.9937 - val_loss: 0.0387 - val_acc: 0.9865 - 6s/epoch - 4ms/step
# Epoch 36/500
# 1342/1342 - 6s - loss: 0.0181 - acc: 0.9939 - val_loss: 0.0449 - val_acc: 0.9842 - 6s/epoch - 4ms/step
# Epoch 37/500
# 1342/1342 - 6s - loss: 0.0176 - acc: 0.9939 - val_loss: 0.0423 - val_acc: 0.9856 - 6s/epoch - 4ms/step
# Epoch 38/500
# 1342/1342 - 6s - loss: 0.0164 - acc: 0.9943 - val_loss: 0.0451 - val_acc: 0.9842 - 6s/epoch - 4ms/step
# Epoch 39/500
# 1342/1342 - 6s - loss: 0.0161 - acc: 0.9944 - val_loss: 0.0388 - val_acc: 0.9868 - 6s/epoch - 4ms/step
# Epoch 40/500
# 1342/1342 - 6s - loss: 0.0147 - acc: 0.9949 - val_loss: 0.0376 - val_acc: 0.9868 - 6s/epoch - 4ms/step
# Epoch 41/500
# 1342/1342 - 6s - loss: 0.0144 - acc: 0.9950 - val_loss: 0.0389 - val_acc: 0.9864 - 6s/epoch - 4ms/step
# Epoch 42/500
# 1342/1342 - 6s - loss: 0.0137 - acc: 0.9954 - val_loss: 0.0396 - val_acc: 0.9868 - 6s/epoch - 4ms/step
# Epoch 43/500
# 1342/1342 - 6s - loss: 0.0136 - acc: 0.9954 - val_loss: 0.0419 - val_acc: 0.9853 - 6s/epoch - 4ms/step

# %%
_, accuracy = model.evaluate([signal_x_test, temp_x_test], y_test)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 4s 2ms/step - loss: 0.0410 - acc: 0.9865
# Test accuracy: 98.65%

# %%
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
import matplotlib.pyplot as plt
metric = "acc"
plt.figure()
plt.plot(history.history[metric], label="train")
plt.plot(history.history["val_" + metric], label="val")
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend()
plt.show()
plt.close()
# Out:
# Test accuracy: 98.65%

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict([signal_x_test, temp_x_test])
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN1D_freq_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 3s 2ms/step

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\freq_all_std_force_quality\Conv1D_freq.h5', save_format="h5")
