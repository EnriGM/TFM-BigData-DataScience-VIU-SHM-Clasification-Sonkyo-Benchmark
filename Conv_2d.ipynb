# %%
import tensorflow as tf
import sklearn
import pandas as pd
from tensorflow.keras import layers, models
from tensorflow import keras
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
tf.random.set_seed(42)
img_directory = r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale"
df = pd.read_csv(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale_case_temp_info.csv",
                header=0, index_col=0)

lb = LabelEncoder()
df["case"] = lb.fit_transform(df["case"])

sc = StandardScaler()
df["temperature"] = sc.fit_transform(df["temperature"].values.reshape(-1, 1))

df_train, df_val = sklearn.model_selection.train_test_split(df, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import math
import os

class CustomDataGenerator(tf.keras.utils.Sequence):

    ''' Custom DataGenerator to load img 
    
    Arguments:
        data_frame = pandas data frame in filenames and labels format
        batch_size = divide data in batches
        shuffle = shuffle data before loading
        img_shape = image shape in (h, w, d) format
        augmentation = data augmentation to make model rebust to overfitting
    
    Output:
        Img: numpy array of image
        label : output label for image
    '''
    
    def __init__(self, data_frame, batch_size=10, img_shape=None, augmentation=True, num_classes=None, folder=""):
        self.data_frame = data_frame
        self.train_len = len(data_frame)
        self.batch_size = batch_size
        self.img_shape = img_shape
        self.num_classes = num_classes
        self.folder = folder
        print(f"Found {self.data_frame.shape[0]} images belonging to {self.num_classes} classes")

    def __len__(self):
        ''' return total number of batches '''
        #self.data_frame = shuffle(self.data_frame)
        return math.ceil(self.train_len/self.batch_size)

    def on_epoch_end(self):
        ''' shuffle data after every epoch '''
        # fix on epoch end it's not working, adding shuffle in len for alternative
        pass
    
    def __data_augmentation(self, img):
        ''' function for apply some data augmentation '''
        img = img/255
        return img
        
    def __get_image(self, file_id):
        """ open image with file_id path and apply data augmentation """
        img = Image.open(os.path.join(self.folder, file_id))
        img = img.resize(self.img_shape, Image.Resampling.LANCZOS)
        img = img.convert("RGB")
        img = tf.keras.preprocessing.image.img_to_array(img) /255
        img = tf.convert_to_tensor(img)
        return img

    def __get_label(self, label_id):
        """ uncomment the below line to convert label into categorical format """
        label_id = tf.keras.utils.to_categorical(label_id, self.num_classes)
        label_id = tf.convert_to_tensor(label_id)
        return label_id

    def __get_temp(self, temp):
        return temp
    
    def __getitem__(self, idx):
        batch_x = self.data_frame["filename"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.data_frame["case"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_temp = self.data_frame["temperature"][idx * self.batch_size:(idx + 1) * self.batch_size]
        # read your data here using the batch lists, batch_x and batch_y
        x = [self.__get_image(file_id) for file_id in batch_x] 
        y = [self.__get_label(label_id) for label_id in batch_y]
        temp = np.array([self.__get_temp(temp) for temp in batch_temp]).T
        data = tf.stack(x)
        label =  tf.stack(y)
        return [data, temp], label

train_generator = CustomDataGenerator(df_train, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
val_generator = CustomDataGenerator(df_val, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
# Out:
# Found 190847 images belonging to 13 classes
# Found 47712 images belonging to 13 classes

# %%
img_input = layers.Input(shape=(224, 224, 3))
temp_input = layers.Input(shape=(1,))

#Train model
conv1 = layers.Conv2D(32, (3, 3), activation='relu')(img_input)
conv2 = layers.Conv2D(32, (3, 3), activation='relu')(conv1)
bn1 = layers.BatchNormalization()(conv2)
mp1 = layers.MaxPooling2D((2, 2))(bn1)
conv3 = layers.Conv2D(64, (3, 3), activation='relu')(mp1)
conv4 = layers.Conv2D(64, (3, 3), activation='relu')(conv3)
bn2 = layers.BatchNormalization()(conv4)
mp2 = layers.MaxPooling2D((2, 2))(bn2)
conv5 = layers.Conv2D(128, (3, 3), activation='relu')(mp2)
gap = layers.GlobalAveragePooling2D()(conv5)

dense_gap = layers.Dense(128, activation='relu')(gap)
dense_temp = layers.Dense(1, activation="relu")(temp_input)

merged = layers.Concatenate(axis=1)([dense_gap, dense_temp])

dense_1 = layers.Dense(128, activation='relu')(merged)
drop_1 = layers.Dropout(0.2)(dense_1)
dense_2 = layers.Dense(64, activation='relu')(drop_1)
drop_2 = layers.Dropout(0.2)(dense_2)
output = layers.Dense(13, activation='softmax')(drop_2)

model = models.Model(inputs=[img_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 220, 220, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 220, 220, 32  128        ['conv2d_1[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 110, 110, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 108, 108, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 106, 106, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 106, 106, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 53, 53, 64)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 51, 51, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['conv2d_4[0][0]']
#  alAveragePooling2D)
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  dense (Dense)                  (None, 128)          16512       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 129)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16640       ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 13)           845         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 182,063
# Trainable params: 181,871
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=["categorical_crossentropy"],
    metrics=['accuracy']
)

# %%
num_epochs = 200

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1)

# Fit the model.

history = model.fit(
    x=train_generator,
    validation_data=val_generator,
    epochs=num_epochs,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
print("end")
# Out:
# Epoch 1/200
# 5964/5964 - 957s - loss: 1.4285 - accuracy: 0.4820 - val_loss: 1.5887 - val_accuracy: 0.4256 - lr: 1.0000e-04 - 957s/epoch - 160ms/step
# Epoch 2/200
# 5964/5964 - 925s - loss: 0.8470 - accuracy: 0.6692 - val_loss: 1.5070 - val_accuracy: 0.4666 - lr: 1.0000e-04 - 925s/epoch - 155ms/step
# Epoch 3/200
# 5964/5964 - 921s - loss: 0.7052 - accuracy: 0.7239 - val_loss: 1.2824 - val_accuracy: 0.5607 - lr: 1.0000e-04 - 921s/epoch - 154ms/step
# Epoch 4/200
# 5964/5964 - 927s - loss: 0.6209 - accuracy: 0.7582 - val_loss: 1.1357 - val_accuracy: 0.6219 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 5/200
# 5964/5964 - 931s - loss: 0.5572 - accuracy: 0.7842 - val_loss: 0.8153 - val_accuracy: 0.7014 - lr: 1.0000e-04 - 931s/epoch - 156ms/step
# Epoch 6/200
# 5964/5964 - 923s - loss: 0.5042 - accuracy: 0.8071 - val_loss: 1.3730 - val_accuracy: 0.5608 - lr: 1.0000e-04 - 923s/epoch - 155ms/step
# Epoch 7/200
# 5964/5964 - 925s - loss: 0.4636 - accuracy: 0.8239 - val_loss: 0.8032 - val_accuracy: 0.7218 - lr: 1.0000e-04 - 925s/epoch - 155ms/step
# Epoch 8/200
# 5964/5964 - 924s - loss: 0.4289 - accuracy: 0.8378 - val_loss: 1.2896 - val_accuracy: 0.6379 - lr: 1.0000e-04 - 924s/epoch - 155ms/step
# Epoch
# Epoch 26/200
# 5964/5964 - 932s - loss: 0.1775 - accuracy: 0.9362 - val_loss: 0.2143 - val_accuracy: 0.9200 - lr: 5.0000e-05 - 932s/epoch - 156ms/step
# Epoch 27/200
# 5964/5964 - 930s - loss: 0.1748 - accuracy: 0.9371 - val_loss: 0.2784 - val_accuracy: 0.8989 - lr: 5.0000e-05 - 930s/epoch - 156ms/step
# Epoch 28/200
# 5964/5964 - 936s - loss: 0.1701 - accuracy: 0.9386 - val_loss: 0.2837 - val_accuracy: 0.8996 - lr: 5.0000e-05 - 936s/epoch - 157ms/step
# Epoch 29/200
# 5964/5964 - 935s - loss: 0.1666 - accuracy: 0.9400 - val_loss: 0.2472 - val_accuracy: 0.9118 - lr: 5.0000e-05 - 935s/epoch - 157ms/step
# Epoch 30/200
# 5964/5964 - 931s - loss: 0.1643 - accuracy: 0.9411 - val_loss: 0.2645 - val_accuracy: 0.9055 - lr: 5.0000e-05 - 931s/epoch - 156ms/step
# Epoch 31/200
# 5964/5964 - 940s - loss: 0.1601 - accuracy: 0.9427 - val_loss: 0.2140 - val_accuracy: 0.9225 - lr: 5.0000e-05 - 940s/epoch - 158ms/step
# Epoch 32/200
# 5964/5964 - 934s - loss: 0.1570 - accuracy: 0.9437 - val_loss: 0.3002 - val_accuracy: 0.9012 - lr: 5.0000e-05 - 934s/epoch - 157ms/step
# Epoch 33/200
# 5964/5964 - 939s - loss: 0.1527 - accuracy: 0.9449 - val_loss: 0.2345 - val_accuracy: 0.9194 - lr: 5.0000e-05 - 939s/epoch - 157ms/step
# Epoch 34/200
# 5964/5964 - 941s - loss: 0.1501 - accuracy: 0.9463 - val_loss: 0.2391 - val_accuracy: 0.9146 - lr: 5.0000e-05 - 941s/epoch - 158ms/step
# Epoch 35/200
# 5964/5964 - 936s - loss: 0.1458 - accuracy: 0.9478 - val_loss: 0.2995 - val_accuracy: 0.8969 - lr: 5.0000e-05 - 936s/epoch - 157ms/step
# Epoch 36/200
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 5964/5964 - 938s - loss: 0.1429 - accuracy: 0.9488 - val_loss: 0.2958 - val_accuracy: 0.8993 - lr: 5.0000e-05 - 938s/epoch - 157ms/step
# Epoch 37/200
# 5964/5964 - 944s - loss: 0.1250 - accuracy: 0.9558 - val_loss: 0.2137 - val_accuracy: 0.9263 - lr: 2.5000e-05 - 944s/epoch - 158ms/step
# Epoch 38/200
# 5964/5964 - 939s - loss: 0.1235 - accuracy: 0.9563 - val_loss: 0.2397 - val_accuracy: 0.9209 - lr: 2.5000e-05 - 939s/epoch - 157ms/step
# Epoch 39/200
# 5964/5964 - 940s - loss: 0.1203 - accuracy: 0.9576 - val_loss: 0.2945 - val_accuracy: 0.8998 - lr: 2.5000e-05 - 940s/epoch - 158ms/step
# Epoch 40/200
# 5964/5964 - 944s - loss: 0.1189 - accuracy: 0.9583 - val_loss: 0.2356 - val_accuracy: 0.9193 - lr: 2.5000e-05 - 944s/epoch - 158ms/step
# Epoch 41/200
# 5964/5964 - 942s - loss: 0.1163 - accuracy: 0.9591 - val_loss: 0.2150 - val_accuracy: 0.9268 - lr: 2.5000e-05 - 942s/epoch - 158ms/step
# Epoch 42/200
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 5964/5964 - 937s - loss: 0.1143 - accuracy: 0.9597 - val_loss: 0.2660 - val_accuracy: 0.9110 - lr: 2.5000e-05 - 937s/epoch - 157ms/step
# Epoch 43/200
# 5964/5964 - 940s - loss: 0.1055 - accuracy: 0.9632 - val_loss: 0.2055 - val_accuracy: 0.9300 - lr: 1.2500e-05 - 940s/epoch - 158ms/step
# Epoch 44/200
# 5964/5964 - 939s - loss: 0.1038 - accuracy: 0.9641 - val_loss: 0.2114 - val_accuracy: 0.9285 - lr: 1.2500e-05 - 939s/epoch - 157ms/step
# Epoch 45/200
# 5964/5964 - 943s - loss: 0.1027 - accuracy: 0.9647 - val_loss: 0.2310 - val_accuracy: 0.9241 - lr: 1.2500e-05 - 943s/epoch - 158ms/step
# Epoch 46/200
# 5964/5964 - 956s - loss: 0.1013 - accuracy: 0.9650 - val_loss: 0.2484 - val_accuracy: 0.9186 - lr: 1.2500e-05 - 956s/epoch - 160ms/step
# Epoch 47/200
# 5964/5964 - 945s - loss: 0.1001 - accuracy: 0.9654 - val_loss: 0.2185 - val_accuracy: 0.9285 - lr: 1.2500e-05 - 945s/epoch - 158ms/step
# Epoch 48/200
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 5964/5964 - 951s - loss: 0.0991 - accuracy: 0.9656 - val_loss: 0.2464 - val_accuracy: 0.9180 - lr: 1.2500e-05 - 951s/epoch - 159ms/step
# Epoch 49/200
# 5964/5964 - 943s - loss: 0.0949 - accuracy: 0.9677 - val_loss: 0.2107 - val_accuracy: 0.9305 - lr: 6.2500e-06 - 943s/epoch - 158ms/step
# Epoch 50/200
# 5964/5964 - 936s - loss: 0.0938 - accuracy: 0.9679 - val_loss: 0.2110 - val_accuracy: 0.9305 - lr: 6.2500e-06 - 936s/epoch - 157ms/step
# Epoch 51/200
# 5964/5964 - 933s - loss: 0.0932 - accuracy: 0.9678 - val_loss: 0.2074 - val_accuracy: 0.9299 - lr: 6.2500e-06 - 933s/epoch - 156ms/step
# Epoch 52/200
# 5964/5964 - 943s - loss: 0.0919 - accuracy: 0.9687 - val_loss: 0.2121 - val_accuracy: 0.9302 - lr: 6.2500e-06 - 943s/epoch - 158ms/step
# Epoch 53/200
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5964/5964 - 941s - loss: 0.0913 - accuracy: 0.9686 - val_loss: 0.2089 - val_accuracy: 0.9321 - lr: 6.2500e-06 - 941s/epoch - 158ms/step
# end

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\cwt_all_std_force_quality\Conv2D.h5', save_format="h5")

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict(val_generator)
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    df_val["case"],
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN2D_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 121s 81ms/step

# %%
_, accuracy = model.evaluate(val_generator)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 123s 82ms/step - loss: 0.2055 - accuracy: 0.9300
# Test accuracy: 93.0%
