# %%
import tensorflow as tf
import sklearn
import pandas as pd
from tensorflow.keras import layers, models
from tensorflow import keras
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
tf.random.set_seed(42)
img_directory = r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale"
df = pd.read_csv(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale_case_temp_info.csv",
                header=0, index_col=0)

lb = LabelEncoder()
df["case"] = lb.fit_transform(df["case"])

sc = StandardScaler()
df["temperature"] = sc.fit_transform(df["temperature"].values.reshape(-1, 1))

df_train, df_val = sklearn.model_selection.train_test_split(df, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import math
import os

class CustomDataGenerator(tf.keras.utils.Sequence):

    ''' Custom DataGenerator to load img 
    
    Arguments:
        data_frame = pandas data frame in filenames and labels format
        batch_size = divide data in batches
        shuffle = shuffle data before loading
        img_shape = image shape in (h, w, d) format
        augmentation = data augmentation to make model rebust to overfitting
    
    Output:
        Img: numpy array of image
        label : output label for image
    '''
    
    def __init__(self, data_frame, batch_size=10, img_shape=None, augmentation=True, num_classes=None, folder=""):
        self.data_frame = data_frame
        self.train_len = len(data_frame)
        self.batch_size = batch_size
        self.img_shape = img_shape
        self.num_classes = num_classes
        self.folder = folder
        print(f"Found {self.data_frame.shape[0]} images belonging to {self.num_classes} classes")

    def __len__(self):
        ''' return total number of batches '''
        #self.data_frame = shuffle(self.data_frame)
        return math.ceil(self.train_len/self.batch_size)

    def on_epoch_end(self):
        ''' shuffle data after every epoch '''
        # fix on epoch end it's not working, adding shuffle in len for alternative
        pass
    
    def __data_augmentation(self, img):
        ''' function for apply some data augmentation '''
        img = img
        return img
        
    def __get_image(self, file_id):
        """ open image with file_id path and apply data augmentation """
        img = Image.open(os.path.join(self.folder, file_id))
        img = img.resize(self.img_shape, Image.Resampling.LANCZOS)
        img = img.convert("RGB")
        img = tf.keras.preprocessing.image.img_to_array(img) /255
        img = tf.convert_to_tensor(img)
        return img

    def __get_label(self, label_id):
        """ uncomment the below line to convert label into categorical format """
        label_id = tf.keras.utils.to_categorical(label_id, self.num_classes)
        label_id = tf.convert_to_tensor(label_id)
        return label_id

    def __get_temp(self, temp):
        return temp
    
    def __getitem__(self, idx):
        batch_x = self.data_frame["filename"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.data_frame["case"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_temp = self.data_frame["temperature"][idx * self.batch_size:(idx + 1) * self.batch_size]
        # read your data here using the batch lists, batch_x and batch_y
        x = [self.__get_image(file_id) for file_id in batch_x] 
        y = [self.__get_label(label_id) for label_id in batch_y]
        temp = np.array([self.__get_temp(temp) for temp in batch_temp]).T
        data = tf.stack(x)
        label =  tf.stack(y)
        return [data, temp], label

train_generator = CustomDataGenerator(df_train, batch_size=32, img_shape=(224, 224), augmentation=False, num_classes=13, folder=img_directory)
val_generator = CustomDataGenerator(df_val, batch_size=32, img_shape=(224, 224), augmentation=False, num_classes=13, folder=img_directory)
# Out:
# Found 190847 images belonging to 13 classes
# Found 47712 images belonging to 13 classes

# %%
img_input = layers.Input(shape=(224, 224, 3))
temp_input = layers.Input(shape=(1,))

#Train model
conv1 = layers.Conv2D(32, (3, 3), activation='relu')(img_input)
conv2 = layers.Conv2D(32, (3, 3), activation='relu')(conv1)
bn1 = layers.BatchNormalization()(conv2)
mp1 = layers.MaxPooling2D((2, 2))(bn1)
conv3 = layers.Conv2D(64, (3, 3), activation='relu')(mp1)
conv4 = layers.Conv2D(64, (3, 3), activation='relu')(conv3)
bn2 = layers.BatchNormalization()(conv4)
mp2 = layers.MaxPooling2D((2, 2))(bn2)
conv5 = layers.Conv2D(128, (3, 3), activation='relu')(mp2)
gap = layers.GlobalAveragePooling2D()(conv5)

dense_gap = layers.Dense(128, activation='relu')(gap)
dense_temp = layers.Dense(1, activation="relu")(temp_input)

merged = layers.Concatenate(axis=1)([dense_gap, dense_temp])

dense_1 = layers.Dense(128, activation='relu')(merged)
drop_1 = layers.Dropout(0.2)(dense_1)
dense_2 = layers.Dense(64, activation='relu')(drop_1)
drop_2 = layers.Dropout(0.2)(dense_2)
output = layers.Dense(13, activation='softmax')(drop_2)

model = models.Model(inputs=[img_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 220, 220, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 220, 220, 32  128        ['conv2d_1[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 110, 110, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 108, 108, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 106, 106, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 106, 106, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 53, 53, 64)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 51, 51, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['conv2d_4[0][0]']
#  alAveragePooling2D)
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  dense (Dense)                  (None, 128)          16512       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 129)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16640       ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 13)           845         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 182,063
# Trainable params: 181,871
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=["categorical_crossentropy"],
    metrics=['accuracy']
)

# %%
num_epochs = 200

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1)

# Fit the model.

history = model.fit(
    x=train_generator,
    validation_data=val_generator,
    epochs=num_epochs,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
print("end")
# Out:
# Epoch 1/200
# 5964/5964 - 923s - loss: 1.3614 - accuracy: 0.5063 - val_loss: 0.8518 - val_accuracy: 0.6671 - lr: 1.0000e-04 - 923s/epoch - 155ms/step
# Epoch 2/200
# 5964/5964 - 927s - loss: 0.8236 - accuracy: 0.6785 - val_loss: 3.6950 - val_accuracy: 0.2115 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 3/200
# 5964/5964 - 933s - loss: 0.6796 - accuracy: 0.7349 - val_loss: 1.2517 - val_accuracy: 0.5768 - lr: 1.0000e-04 - 933s/epoch - 156ms/step
# Epoch 4/200
# 5964/5964 - 937s - loss: 0.5874 - accuracy: 0.7739 - val_loss: 3.6385 - val_accuracy: 0.3615 - lr: 1.0000e-04 - 937s/epoch - 157ms/step
# Epoch 5/200
# 5964/5964 - 925s - loss: 0.5236 - accuracy: 0.7998 - val_loss: 1.0267 - val_accuracy: 0.6319 - lr: 1.0000e-04 - 925s/epoch - 155ms/step
# Epoch 6/200
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5964/5964 - 915s - loss: 0.4733 - accuracy: 0.8205 - val_loss: 0.9559 - val_accuracy: 0.6869 - lr: 1.0000e-04 - 915s/epoch - 153ms/step
# Epoch 7/200
# 5964/5964 - 922s - loss: 0.4138 - accuracy: 0.8436 - val_loss: 1.4718 - val_accuracy: 0.5474 - lr: 5.0000e-05 - 922s/epoch - 155ms/step
# Epoch 8/200
# 5964/5964 - 913s - loss: 0.3923 - accuracy: 0.8523 - val_loss: 0.4788 - val_accuracy: 0.8187 - lr: 5.0000e-05 - 913s/epoch - 153ms/step
# Epoch 9/200
# 5964/5964 - 915s - loss: 0.3772 - accuracy: 0.8587 - val_loss: 0.5970 - val_accuracy: 0.7744 - lr: 5.0000e-05 - 915s/epoch - 153ms/step
# Epoch 10/200
# 5964/5964 - 926s - loss: 0.3633 - accuracy: 0.8639 - val_loss: 0.8302 - val_accuracy: 0.7032 - lr: 5.0000e-05 - 926s/epoch - 155ms/step
# Epoch 11/200
# 5964/5964 - 917s - loss: 0.3483 - accuracy: 0.8699 - val_loss: 0.4536 - val_accuracy: 0.8238 - lr: 5.0000e-05 - 917s/epoch - 154ms/step
# Epoch 12/200
# 5964/5964 - 921s - loss: 0.3359 - accuracy: 0.8753 - val_loss: 0.4219 - val_accuracy: 0.8408 - lr: 5.0000e-05 - 921s/epoch - 154ms/step
