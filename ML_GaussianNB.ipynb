# %% [markdown]
# Gaussian time

# %%
import numpy as np

x = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality\x_for_ml.npy")
y = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality\y_for_ml.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score
from datetime import datetime

print(datetime.now())

n_iter_search = 2

param_dist = {"var_smoothing":[1e-9, 1e-8, 1e-10, 1e-7, 1e-11],
}

clf = GaussianNB()
print("start random search")
random_search = RandomizedSearchCV(
    clf, param_distributions=param_dist, n_iter=n_iter_search,
    random_state=SEED, verbose=3)

random_search.fit(X_train, y_train)
print(random_search.best_params_)
model = random_search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
print(datetime.now())
# Out:
# 2026-01-22 19:43:36.455786
# start random search
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END ...............var_smoothing=1e-08;, score=0.200 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-08;, score=0.191 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-08;, score=0.201 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-08;, score=0.197 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-08;, score=0.171 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-11;, score=0.200 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-11;, score=0.191 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-11;, score=0.201 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-11;, score=0.197 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-11;, score=0.171 total time=   0.0s
# {'var_smoothing': 1e-08}
# precision 0.20261150234741784
# 2026-01-22 19:43:37.724409

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score
from sklearn.model_selection import GridSearchCV

param_dist = {"var_smoothing":[1e-9, 1e-8, 1e-10]
              }

clf = GaussianNB()
print("start random search")
search = GridSearchCV(clf, param_grid=param_dist, verbose=3)

search.fit(X_train, y_train)
print(search.best_params_)
model = search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
# Out:
# start random search
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ...............var_smoothing=1e-09;, score=0.200 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-09;, score=0.191 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-09;, score=0.201 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-09;, score=0.197 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-09;, score=0.171 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-08;, score=0.200 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-08;, score=0.191 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-08;, score=0.201 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-08;, score=0.197 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-08;, score=0.171 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-10;, score=0.200 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-10;, score=0.191 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-10;, score=0.201 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-10;, score=0.197 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-10;, score=0.171 total time=   0.0s
# {'var_smoothing': 1e-09}
# precision 0.20261150234741784

# %%
import pickle 

with open(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\time_all_std_force_quality\Gaussian_NB_time.pickle', 'wb') as f:
    pickle.dump(model, f)

# %% [markdown]
# Gaussian Freq

# %%
import numpy as np

x = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality_freq\x_for_ml.npy")
y = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality_freq\y_for_ml.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score
from datetime import datetime

print(datetime.now())

n_iter_search = 2

param_dist = {"var_smoothing":[1e-9, 1e-8, 1e-10, 1e-7, 1e-11],
}

clf = GaussianNB()
print("start random search")
random_search = RandomizedSearchCV(
    clf, param_distributions=param_dist, n_iter=n_iter_search,
    random_state=SEED, verbose=3)

random_search.fit(X_train, y_train)
print(random_search.best_params_)
model = random_search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
print(datetime.now())
# Out:
# 2026-01-22 19:43:39.667252
# start random search
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END ...............var_smoothing=1e-08;, score=0.239 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-08;, score=0.240 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-08;, score=0.239 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-08;, score=0.238 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-08;, score=0.237 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-11;, score=0.239 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-11;, score=0.240 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-11;, score=0.239 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-11;, score=0.238 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-11;, score=0.237 total time=   0.0s
# {'var_smoothing': 1e-08}
# precision 0.2363137156270959
# 2026-01-22 19:43:40.921912

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score
from sklearn.model_selection import GridSearchCV

param_dist = {"var_smoothing":[1e-10, 1e-11, 1e-12]
              }

clf = GaussianNB()
print("start random search")
search = GridSearchCV(clf, param_grid=param_dist, verbose=3)

search.fit(X_train, y_train)
print(search.best_params_)
model = search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
# Out:
# start random search
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ...............var_smoothing=1e-10;, score=0.239 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-10;, score=0.240 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-10;, score=0.239 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-10;, score=0.238 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-10;, score=0.237 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-11;, score=0.239 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-11;, score=0.240 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-11;, score=0.239 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-11;, score=0.238 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-11;, score=0.237 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-12;, score=0.239 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-12;, score=0.240 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-12;, score=0.239 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-12;, score=0.238 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-12;, score=0.237 total time=   0.0s
# {'var_smoothing': 1e-10}
# precision 0.2363137156270959

# %%
import pickle 

with open(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\freq_all_std_force_quality\Gaussian_NB_freq.pickle', 'wb') as f:
    pickle.dump(model, f)
