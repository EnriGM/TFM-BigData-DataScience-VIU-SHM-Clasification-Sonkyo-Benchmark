# %%
import tensorflow as tf
import sklearn
import pandas as pd
from tensorflow.keras import layers, models
from tensorflow import keras
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
tf.random.set_seed(42)
img_directory = r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale"
df = pd.read_csv(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale_case_temp_info.csv",
                header=0, index_col=0)

lb = LabelEncoder()
df["case"] = lb.fit_transform(df["case"])

sc = StandardScaler()
df["temperature"] = sc.fit_transform(df["temperature"].values.reshape(-1, 1))

df_train, df_val = sklearn.model_selection.train_test_split(df, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import math
import os

class CustomDataGenerator(tf.keras.utils.Sequence):

    ''' Custom DataGenerator to load img 
    
    Arguments:
        data_frame = pandas data frame in filenames and labels format
        batch_size = divide data in batches
        shuffle = shuffle data before loading
        img_shape = image shape in (h, w, d) format
        augmentation = data augmentation to make model rebust to overfitting
    
    Output:
        Img: numpy array of image
        label : output label for image
    '''
    
    def __init__(self, data_frame, batch_size=10, img_shape=None, augmentation=True, num_classes=None, folder=""):
        self.data_frame = data_frame
        self.train_len = len(data_frame)
        self.batch_size = batch_size
        self.img_shape = img_shape
        self.num_classes = num_classes
        self.folder = folder
        print(f"Found {self.data_frame.shape[0]} images belonging to {self.num_classes} classes")

    def __len__(self):
        ''' return total number of batches '''
        #self.data_frame = shuffle(self.data_frame)
        return math.ceil(self.train_len/self.batch_size)

    def on_epoch_end(self):
        ''' shuffle data after every epoch '''
        # fix on epoch end it's not working, adding shuffle in len for alternative
        pass
    
    def __data_augmentation(self, img):
        ''' function for apply some data augmentation '''
        img = img/255
        return img
        
    def __get_image(self, file_id):
        """ open image with file_id path and apply data augmentation """
        img = Image.open(os.path.join(self.folder, file_id))
        img = img.resize(self.img_shape, Image.Resampling.LANCZOS)
        img = img.convert("RGB")
        img = tf.keras.preprocessing.image.img_to_array(img) # /255 removed for EfficientNetV2B0
        img = tf.convert_to_tensor(img)
        return img

    def __get_label(self, label_id):
        """ uncomment the below line to convert label into categorical format """
        label_id = tf.keras.utils.to_categorical(label_id, self.num_classes)
        label_id = tf.convert_to_tensor(label_id)
        return label_id

    def __get_temp(self, temp):
        return temp
    
    def __getitem__(self, idx):
        batch_x = self.data_frame["filename"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.data_frame["case"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_temp = self.data_frame["temperature"][idx * self.batch_size:(idx + 1) * self.batch_size]
        # read your data here using the batch lists, batch_x and batch_y
        x = [self.__get_image(file_id) for file_id in batch_x] 
        y = [self.__get_label(label_id) for label_id in batch_y]
        temp = np.array([self.__get_temp(temp) for temp in batch_temp]).T
        data = tf.stack(x)
        label =  tf.stack(y)
        return [data, temp], label

train_generator = CustomDataGenerator(df_train, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
val_generator = CustomDataGenerator(df_val, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
# Out:
# Found 190847 images belonging to 13 classes
# Found 47712 images belonging to 13 classes

# %%
from tensorflow.keras.applications import EfficientNetV2B0
img_input = layers.Input(shape=(224, 224, 3))
temp_input = layers.Input(shape=(1,))

#Transfer learning model
base_model = EfficientNetV2B0(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

base_model.trainable = True  
#activamos solo las últimas 10 capas
for layer in base_model.layers[:-10]:
    layer.trainable = False
    
x = base_model(img_input)
"""
for count, layer in enumerate(base_model.layers):
    print(count, layer._name)
"""
# Out:
# '\nfor count, layer in enumerate(base_model.layers):\n    print(count, layer._name)\n'

# %%
gap = layers.GlobalAveragePooling2D()(x)

dense_gap = layers.Dense(128, activation='relu')(gap)
dense_temp = layers.Dense(1, activation="relu")(temp_input)

merged = layers.Concatenate(axis=1)([dense_gap, dense_temp])

dense_1 = layers.Dense(128, activation='relu')(merged)
drop_1 = layers.Dropout(0.2)(dense_1)
dense_2 = layers.Dense(64, activation='relu')(drop_1)
drop_2 = layers.Dropout(0.2)(dense_2)
output = layers.Dense(13, activation='softmax')(drop_2)

model = models.Model(inputs=[img_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  efficientnetv2-b0 (Functional)  (None, 7, 7, 1280)  5919312     ['input_16[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1280)        0           ['efficientnetv2-b0[0][0]']
#  obalAveragePooling2D)
#
#  input_17 (InputLayer)          [(None, 1)]          0           []
#
#  dense_10 (Dense)               (None, 128)          163968      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_11 (Dense)               (None, 1)            2           ['input_17[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 129)          0           ['dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 128)          16640       ['concatenate_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 64)           8256        ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 64)           0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 13)           845         ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 6,109,023
# Trainable params: 771,391
# Non-trainable params: 5,337,632
# __________________________________________________________________________________________________

# %%
learning_rate = 0.001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=["categorical_crossentropy"],
    metrics=['accuracy']
)

# %%
num_epochs = 200

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-4,
    verbose=1)

# Fit the model.

history = model.fit(
    x=train_generator,
    validation_data=val_generator,
    epochs=num_epochs,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
print("end")
# Out:
# Epoch 1/200
# 5964/5964 - 789s - loss: 1.0265 - accuracy: 0.6164 - val_loss: 0.6831 - val_accuracy: 0.7394 - lr: 0.0010 - 789s/epoch - 132ms/step
# Epoch 2/200
# 5964/5964 - 764s - loss: 0.7523 - accuracy: 0.7173 - val_loss: 0.5724 - val_accuracy: 0.7812 - lr: 0.0010 - 764s/epoch - 128ms/step
# Epoch 3/200
# 5964/5964 - 745s - loss: 0.6811 - accuracy: 0.7446 - val_loss: 0.5798 - val_accuracy: 0.7794 - lr: 0.0010 - 745s/epoch - 125ms/step
# Epoch 4/200
# 5964/5964 - 751s - loss: 0.6385 - accuracy: 0.7621 - val_loss: 0.5274 - val_accuracy: 0.8002 - lr: 0.0010 - 751s/epoch - 126ms/step
# Epoch 5/200
# 5964/5964 - 765s - loss: 0.6104 - accuracy: 0.7736 - val_loss: 0.5058 - val_accuracy: 0.8042 - lr: 0.0010 - 765s/epoch - 128ms/step
# Epoch 6/200
# 5964/5964 - 748s - loss: 0.5894 - accuracy: 0.7805 - val_loss: 0.4877 - val_accuracy: 0.8168 - lr: 0.0010 - 748s/epoch - 125ms/step
# Epoch 7/200
# 5964/5964 - 750s - loss: 0.5721 - accuracy: 0.7883 - val_loss: 0.5089 - val_accuracy: 0.8094 - lr: 0.0010 - 750s/epoch - 126ms/step
# Epoch 8/200
# 5964/5964 - 751s - loss: 0.5532 - accuracy: 0.7945 - val_loss: 0.4510 - val_accuracy: 0.8295 - lr: 0.0010 - 751s/epoch - 126ms/step
# Epoch 9/200
# 5964/5964 - 739s - loss: 0.5439 - accuracy: 0.7992 - val_loss: 0.4770 - val_accuracy: 0.8206 - lr: 0.0010 - 739s/epoch - 124ms/step
# Epoch 10/200
# 5964/5964 - 741s - loss: 0.5329 - accuracy: 0.8035 - val_loss: 0.4702 - val_accuracy: 0.8208 - lr: 0.0010 - 741s/epoch - 124ms/step
# Epoch 11/200
# 5964/5964 - 756s - loss: 0.5247 - accuracy: 0.8059 - val_loss: 0.4573 - val_accuracy: 0.8221 - lr: 0.0010 - 756s/epoch - 127ms/step
# Epoch 12/200
# 5964/5964 - 757s - loss: 0.5139 - accuracy: 0.8098 - val_loss: 0.4499 - val_accuracy: 0.8299 - lr: 0.0010 - 757s/epoch - 127ms/step
# Epoch 13/200
# 5964/5964 - 742s - loss: 0.5082 - accuracy: 0.8124 - val_loss: 0.4636 - val_accuracy: 0.8216 - lr: 0.0010 - 742s/epoch - 124ms/step
# Epoch 14/200
# 5964/5964 - 757s - loss: 0.4985 - accuracy: 0.8149 - val_loss: 0.4527 - val_accuracy: 0.8290 - lr: 0.0010 - 757s/epoch - 127ms/step
# Epoch 15/200
# 5964/5964 - 759s - loss: 0.4926 - accuracy: 0.8179 - val_loss: 0.4596 - val_accuracy: 0.8270 - lr: 0.0010 - 759s/epoch - 127ms/step
# Epoch 16/200
# 5964/5964 - 762s - loss: 0.4872 - accuracy: 0.8200 - val_loss: 0.4452 - val_accuracy: 0.8324 - lr: 0.0010 - 762s/epoch - 128ms/step
# Epoch 17/200
# 5964/5964 - 752s - loss: 0.4824 - accuracy: 0.8216 - val_loss: 0.4541 - val_accuracy: 0.8282 - lr: 0.0010 - 752s/epoch - 126ms/step
# Epoch 18/200
# 5964/5964 - 764s - loss: 0.4751 - accuracy: 0.8245 - val_loss: 0.4362 - val_accuracy: 0.8346 - lr: 0.0010 - 764s/epoch - 128ms/step
# Epoch 19/200
# 5964/5964 - 758s - loss: 0.4695 - accuracy: 0.8280 - val_loss: 0.4357 - val_accuracy: 0.8349 - lr: 0.0010 - 758s/epoch - 127ms/step
# Epoch 20/200
# 5964/5964 - 752s - loss: 0.4653 - accuracy: 0.8288 - val_loss: 0.4369 - val_accuracy: 0.8361 - lr: 0.0010 - 752s/epoch - 126ms/step
# Epoch 21/200
# 5964/5964 - 766s - loss: 0.4606 - accuracy: 0.8303 - val_loss: 0.4449 - val_accuracy: 0.8320 - lr: 0.0010 - 766s/epoch - 128ms/step
# Epoch 22/200
# 5964/5964 - 751s - loss: 0.4570 - accuracy: 0.8318 - val_loss: 0.4159 - val_accuracy: 0.8434 - lr: 0.0010 - 751s/epoch - 126ms/step
# Epoch 23/200
# 5964/5964 - 761s - loss: 0.4495 - accuracy: 0.8351 - val_loss: 0.4393 - val_accuracy: 0.8358 - lr: 0.0010 - 761s/epoch - 128ms/step
# Epoch 24/200
# 5964/5964 - 766s - loss: 0.4477 - accuracy: 0.8359 - val_loss: 0.4311 - val_accuracy: 0.8351 - lr: 0.0010 - 766s/epoch - 128ms/step
# Epoch 25/200
# 5964/5964 - 753s - loss: 0.4427 - accuracy: 0.8369 - val_loss: 0.4313 - val_accuracy: 0.8384 - lr: 0.0010 - 753s/epoch - 126ms/step
# Epoch 26/200
# 5964/5964 - 759s - loss: 0.4365 - accuracy: 0.8394 - val_loss: 0.4494 - val_accuracy: 0.8328 - lr: 0.0010 - 759s/epoch - 127ms/step
# Epoch 27/200
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5964/5964 - 769s - loss: 0.4339 - accuracy: 0.8410 - val_loss: 0.4336 - val_accuracy: 0.8386 - lr: 0.0010 - 769s/epoch - 129ms/step
# Epoch 28/200
# 5964/5964 - 756s - loss: 0.3830 - accuracy: 0.8586 - val_loss: 0.4060 - val_accuracy: 0.8494 - lr: 5.0000e-04 - 756s/epoch - 127ms/step
# Epoch 29/200
# 5964/5964 - 762s - loss: 0.3715 - accuracy: 0.8634 - val_loss: 0.4072 - val_accuracy: 0.8503 - lr: 5.0000e-04 - 762s/epoch - 128ms/step
# Epoch 30/200
# 5964/5964 - 768s - loss: 0.3666 - accuracy: 0.8657 - val_loss: 0.4015 - val_accuracy: 0.8507 - lr: 5.0000e-04 - 768s/epoch - 129ms/step
# Epoch 31/200
# 5964/5964 - 757s - loss: 0.3630 - accuracy: 0.8664 - val_loss: 0.4060 - val_accuracy: 0.8513 - lr: 5.0000e-04 - 757s/epoch - 127ms/step
# Epoch 32/200
# 5964/5964 - 764s - loss: 0.3579 - accuracy: 0.8689 - val_loss: 0.4184 - val_accuracy: 0.8469 - lr: 5.0000e-04 - 764s/epoch - 128ms/step
# Epoch 33/200
# 5964/5964 - 772s - loss: 0.3561 - accuracy: 0.8694 - val_loss: 0.4128 - val_accuracy: 0.8496 - lr: 5.0000e-04 - 772s/epoch - 129ms/step
# Epoch 34/200
# 5964/5964 - 757s - loss: 0.3529 - accuracy: 0.8710 - val_loss: 0.4131 - val_accuracy: 0.8489 - lr: 5.0000e-04 - 757s/epoch - 127ms/step
# Epoch 35/200
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5964/5964 - 761s - loss: 0.3486 - accuracy: 0.8722 - val_loss: 0.4065 - val_accuracy: 0.8508 - lr: 5.0000e-04 - 761s/epoch - 128ms/step
# Epoch 36/200
# 5964/5964 - 775s - loss: 0.3240 - accuracy: 0.8812 - val_loss: 0.4055 - val_accuracy: 0.8551 - lr: 2.5000e-04 - 775s/epoch - 130ms/step
# Epoch 37/200
# 5964/5964 - 761s - loss: 0.3176 - accuracy: 0.8839 - val_loss: 0.4031 - val_accuracy: 0.8539 - lr: 2.5000e-04 - 761s/epoch - 128ms/step
# Epoch 38/200
# 5964/5964 - 768s - loss: 0.3135 - accuracy: 0.8851 - val_loss: 0.4119 - val_accuracy: 0.8524 - lr: 2.5000e-04 - 768s/epoch - 129ms/step
# Epoch 39/200
# 5964/5964 - 772s - loss: 0.3094 - accuracy: 0.8867 - val_loss: 0.4133 - val_accuracy: 0.8529 - lr: 2.5000e-04 - 772s/epoch - 129ms/step
# Epoch 40/200
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5964/5964 - 759s - loss: 0.3088 - accuracy: 0.8865 - val_loss: 0.4118 - val_accuracy: 0.8542 - lr: 2.5000e-04 - 759s/epoch - 127ms/step
# end

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\cwt_all_std_force_quality\Conv2D_transfer_fine_tuned.h5', save_format="h5")

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict(val_generator)
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    df_val["case"],
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN2D_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 129s 86ms/step

# %%
_, accuracy = model.evaluate(val_generator)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 129s 87ms/step - loss: 0.4015 - accuracy: 0.8507
# Test accuracy: 85.07%
