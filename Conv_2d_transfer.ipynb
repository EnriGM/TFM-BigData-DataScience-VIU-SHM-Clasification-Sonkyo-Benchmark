# %%
import tensorflow as tf
import sklearn
import pandas as pd
from tensorflow.keras import layers, models
from tensorflow import keras
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
tf.random.set_seed(42)
img_directory = r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale"
df = pd.read_csv(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale_case_temp_info.csv",
                header=0, index_col=0)

lb = LabelEncoder()
df["case"] = lb.fit_transform(df["case"])

sc = StandardScaler()
df["temperature"] = sc.fit_transform(df["temperature"].values.reshape(-1, 1))

df_train, df_val = sklearn.model_selection.train_test_split(df, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import math
import os

class CustomDataGenerator(tf.keras.utils.Sequence):

    ''' Custom DataGenerator to load img 
    
    Arguments:
        data_frame = pandas data frame in filenames and labels format
        batch_size = divide data in batches
        shuffle = shuffle data before loading
        img_shape = image shape in (h, w, d) format
        augmentation = data augmentation to make model rebust to overfitting
    
    Output:
        Img: numpy array of image
        label : output label for image
    '''
    
    def __init__(self, data_frame, batch_size=10, img_shape=None, augmentation=True, num_classes=None, folder=""):
        self.data_frame = data_frame
        self.train_len = len(data_frame)
        self.batch_size = batch_size
        self.img_shape = img_shape
        self.num_classes = num_classes
        self.folder = folder
        print(f"Found {self.data_frame.shape[0]} images belonging to {self.num_classes} classes")

    def __len__(self):
        ''' return total number of batches '''
        #self.data_frame = shuffle(self.data_frame)
        return math.ceil(self.train_len/self.batch_size)

    def on_epoch_end(self):
        ''' shuffle data after every epoch '''
        # fix on epoch end it's not working, adding shuffle in len for alternative
        pass
    
    def __data_augmentation(self, img):
        ''' function for apply some data augmentation '''
        img = img
        return img
        
    def __get_image(self, file_id):
        """ open image with file_id path and apply data augmentation """
        img = Image.open(os.path.join(self.folder, file_id))
        img = img.resize(self.img_shape, Image.Resampling.LANCZOS)
        img = img.convert("RGB")
        img = tf.keras.preprocessing.image.img_to_array(img) # /255 removed for EfficientNetV2B0
        img = tf.convert_to_tensor(img)
        return img

    def __get_label(self, label_id):
        """ uncomment the below line to convert label into categorical format """
        label_id = tf.keras.utils.to_categorical(label_id, self.num_classes)
        label_id = tf.convert_to_tensor(label_id)
        return label_id

    def __get_temp(self, temp):
        return temp
    
    def __getitem__(self, idx):
        batch_x = self.data_frame["filename"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.data_frame["case"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_temp = self.data_frame["temperature"][idx * self.batch_size:(idx + 1) * self.batch_size]
        # read your data here using the batch lists, batch_x and batch_y
        x = [self.__get_image(file_id) for file_id in batch_x] 
        y = [self.__get_label(label_id) for label_id in batch_y]
        temp = np.array([self.__get_temp(temp) for temp in batch_temp]).T
        data = tf.stack(x)
        label =  tf.stack(y)
        return [data, temp], label

train_generator = CustomDataGenerator(df_train, batch_size=32, img_shape=(224, 224), augmentation=False, num_classes=13, folder=img_directory)
val_generator = CustomDataGenerator(df_val, batch_size=32, img_shape=(224, 224), augmentation=False, num_classes=13, folder=img_directory)
# Out:
# Found 190847 images belonging to 13 classes
# Found 47712 images belonging to 13 classes

# %%
from tensorflow.keras.applications import EfficientNetV2B0
img_input = layers.Input(shape=(224, 224, 3))
temp_input = layers.Input(shape=(1,))

#Transfer learning model
base_model = EfficientNetV2B0(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

base_model.trainable = False  # Congelamos el modelo base

x = base_model(img_input)

gap = layers.GlobalAveragePooling2D()(x)

dense_gap = layers.Dense(128, activation='relu')(gap)
dense_temp = layers.Dense(1, activation="relu")(temp_input)

merged = layers.Concatenate(axis=1)([dense_gap, dense_temp])

dense_1 = layers.Dense(128, activation='relu')(merged)
drop_1 = layers.Dropout(0.2)(dense_1)
dense_2 = layers.Dense(64, activation='relu')(drop_1)
drop_2 = layers.Dropout(0.2)(dense_2)
output = layers.Dense(13, activation='softmax')(drop_2)

model = models.Model(inputs=[img_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  efficientnetv2-b0 (Functional)  (None, 7, 7, 1280)  5919312     ['input_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['efficientnetv2-b0[0][0]']
#  alAveragePooling2D)
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  dense (Dense)                  (None, 128)          163968      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 129)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16640       ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 13)           845         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 6,109,023
# Trainable params: 189,711
# Non-trainable params: 5,919,312
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=["categorical_crossentropy"],
    metrics=['accuracy']
)

# %%
num_epochs = 200

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1)

# Fit the model.

history = model.fit(
    x=train_generator,
    validation_data=val_generator,
    epochs=num_epochs,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
print("end")
# Out:
# Epoch 1/200
# 5964/5964 - 790s - loss: 1.8125 - accuracy: 0.3644 - val_loss: 1.3566 - val_accuracy: 0.5089 - lr: 1.0000e-04 - 790s/epoch - 133ms/step
# Epoch 2/200
# 5964/5964 - 770s - loss: 1.3870 - accuracy: 0.4866 - val_loss: 1.1448 - val_accuracy: 0.5721 - lr: 1.0000e-04 - 770s/epoch - 129ms/step
# Epoch 3/200
# 5964/5964 - 771s - loss: 1.2399 - accuracy: 0.5328 - val_loss: 1.0188 - val_accuracy: 0.6132 - lr: 1.0000e-04 - 771s/epoch - 129ms/step
# Epoch 4/200
# 5964/5964 - 771s - loss: 1.1542 - accuracy: 0.5639 - val_loss: 0.9878 - val_accuracy: 0.6247 - lr: 1.0000e-04 - 771s/epoch - 129ms/step
# Epoch 5/200
# 5964/5964 - 773s - loss: 1.0945 - accuracy: 0.5846 - val_loss: 0.9022 - val_accuracy: 0.6603 - lr: 1.0000e-04 - 773s/epoch - 130ms/step
# Epoch 6/200
# 5964/5964 - 786s - loss: 1.0525 - accuracy: 0.5997 - val_loss: 0.8815 - val_accuracy: 0.6623 - lr: 1.0000e-04 - 786s/epoch - 132ms/step
# Epoch 7/200
# 5964/5964 - 784s - loss: 1.0201 - accuracy: 0.6132 - val_loss: 0.8560 - val_accuracy: 0.6706 - lr: 1.0000e-04 - 784s/epoch - 131ms/step
# Epoch 8/200
# 5964/5964 - 773s - loss: 0.9905 - accuracy: 0.6230 - val_loss: 0.8335 - val_accuracy: 0.6801 - lr: 1.0000e-04 - 773s/epoch - 130ms/step
# Epoch 9/200
# 5964/5964 - 780s - loss: 0.9679 - accuracy: 0.6321 - val_loss: 0.8015 - val_accuracy: 0.6942 - lr: 1.0000e-04 - 780s/epoch - 131ms/step
# Epoch 10/200
# 5964/5964 - 774s - loss: 0.9495 - accuracy: 0.6400 - val_loss: 0.8328 - val_accuracy: 0.6817 - lr: 1.0000e-04 - 774s/epoch - 130ms/step
# Epoch 11/200
# Epoch 41/200
# 5964/5964 - 799s - loss: 0.7584 - accuracy: 0.7155 - val_loss: 0.6201 - val_accuracy: 0.7655 - lr: 1.0000e-04 - 799s/epoch - 134ms/step
# Epoch 42/200
# 5964/5964 - 793s - loss: 0.7567 - accuracy: 0.7160 - val_loss: 0.6085 - val_accuracy: 0.7689 - lr: 1.0000e-04 - 793s/epoch - 133ms/step
# Epoch 43/200
# 5964/5964 - 823s - loss: 0.7517 - accuracy: 0.7189 - val_loss: 0.6313 - val_accuracy: 0.7604 - lr: 1.0000e-04 - 823s/epoch - 138ms/step
# Epoch 44/200
# 5964/5964 - 795s - loss: 0.7509 - accuracy: 0.7184 - val_loss: 0.6162 - val_accuracy: 0.7683 - lr: 1.0000e-04 - 795s/epoch - 133ms/step
# Epoch 45/200
# 5964/5964 - 798s - loss: 0.7468 - accuracy: 0.7204 - val_loss: 0.5944 - val_accuracy: 0.7750 - lr: 1.0000e-04 - 798s/epoch - 134ms/step
# Epoch 46/200
# 5964/5964 - 803s - loss: 0.7477 - accuracy: 0.7191 - val_loss: 0.5948 - val_accuracy: 0.7749 - lr: 1.0000e-04 - 803s/epoch - 135ms/step
# Epoch 47/200
# 5964/5964 - 806s - loss: 0.7452 - accuracy: 0.7206 - val_loss: 0.5945 - val_accuracy: 0.7759 - lr: 1.0000e-04 - 806s/epoch - 135ms/step
# Epoch 48/200
# 5964/5964 - 800s - loss: 0.7426 - accuracy: 0.7205 - val_loss: 0.6205 - val_accuracy: 0.7656 - lr: 1.0000e-04 - 800s/epoch - 134ms/step
# Epoch 49/200
# 5964/5964 - 803s - loss: 0.7372 - accuracy: 0.7225 - val_loss: 0.6017 - val_accuracy: 0.7705 - lr: 1.0000e-04 - 803s/epoch - 135ms/step
# Epoch 50/200
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5964/5964 - 797s - loss: 0.7355 - accuracy: 0.7235 - val_loss: 0.6001 - val_accuracy: 0.7719 - lr: 1.0000e-04 - 797s/epoch - 134ms/step
# Epoch 51/200
# 5964/5964 - 817s - loss: 0.7130 - accuracy: 0.7337 - val_loss: 0.5900 - val_accuracy: 0.7775 - lr: 5.0000e-05 - 817s/epoch - 137ms/step
# Epoch 52/200
# 5964/5964 - 799s - loss: 0.7094 - accuracy: 0.7336 - val_loss: 0.5890 - val_accuracy: 0.7780 - lr: 5.0000e-05 - 799s/epoch - 134ms/step
# Epoch 53/200
# 5964/5964 - 798s - loss: 0.7069 - accuracy: 0.7343 - val_loss: 0.5746 - val_accuracy: 0.7838 - lr: 5.0000e-05 - 798s/epoch - 134ms/step
# Epoch 54/200
# 5964/5964 - 805s - loss: 0.7079 - accuracy: 0.7344 - val_loss: 0.5871 - val_accuracy: 0.7784 - lr: 5.0000e-05 - 805s/epoch - 135ms/step
# Epoch 55/200
# 5964/5964 - 803s - loss: 0.7061 - accuracy: 0.7351 - val_loss: 0.5692 - val_accuracy: 0.7863 - lr: 5.0000e-05 - 803s/epoch - 135ms/step
# Epoch 56/200
# 5964/5964 - 805s - loss: 0.7035 - accuracy: 0.7349 - val_loss: 0.5844 - val_accuracy: 0.7785 - lr: 5.0000e-05 - 805s/epoch - 135ms/step
# Epoch 57/200
# 5964/5964 - 799s - loss: 0.7025 - accuracy: 0.7367 - val_loss: 0.5848 - val_accuracy: 0.7777 - lr: 5.0000e-05 - 799s/epoch - 134ms/step
# Epoch 58/200
# 5964/5964 - 800s - loss: 0.7019 - accuracy: 0.7370 - val_loss: 0.5931 - val_accuracy: 0.7748 - lr: 5.0000e-05 - 800s/epoch - 134ms/step
# Epoch 59/200
# 5964/5964 - 799s - loss: 0.6999 - accuracy: 0.7385 - val_loss: 0.5889 - val_accuracy: 0.7761 - lr: 5.0000e-05 - 799s/epoch - 134ms/step
# Epoch 60/200
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 5964/5964 - 798s - loss: 0.7020 - accuracy: 0.7380 - val_loss: 0.5845 - val_accuracy: 0.7818 - lr: 5.0000e-05 - 798s/epoch - 134ms/step
# Epoch 61/200
# 5964/5964 - 798s - loss: 0.6856 - accuracy: 0.7435 - val_loss: 0.5621 - val_accuracy: 0.7875 - lr: 2.5000e-05 - 798s/epoch - 134ms/step
# Epoch 62/200
# 5964/5964 - 811s - loss: 0.6858 - accuracy: 0.7429 - val_loss: 0.5796 - val_accuracy: 0.7812 - lr: 2.5000e-05 - 811s/epoch - 136ms/step
# Epoch 63/200
# 5964/5964 - 796s - loss: 0.6841 - accuracy: 0.7439 - val_loss: 0.5617 - val_accuracy: 0.7876 - lr: 2.5000e-05 - 796s/epoch - 133ms/step
# Epoch 64/200
# 5964/5964 - 805s - loss: 0.6851 - accuracy: 0.7430 - val_loss: 0.5629 - val_accuracy: 0.7871 - lr: 2.5000e-05 - 805s/epoch - 135ms/step
# Epoch 65/200
# 5964/5964 - 800s - loss: 0.6829 - accuracy: 0.7437 - val_loss: 0.5642 - val_accuracy: 0.7869 - lr: 2.5000e-05 - 800s/epoch - 134ms/step
# Epoch 66/200
# 5964/5964 - 814s - loss: 0.6855 - accuracy: 0.7442 - val_loss: 0.5588 - val_accuracy: 0.7891 - lr: 2.5000e-05 - 814s/epoch - 136ms/step
# Epoch 67/200
# 5964/5964 - 808s - loss: 0.6828 - accuracy: 0.7449 - val_loss: 0.5593 - val_accuracy: 0.7887 - lr: 2.5000e-05 - 808s/epoch - 136ms/step
# Epoch 68/200
# 5964/5964 - 808s - loss: 0.6820 - accuracy: 0.7446 - val_loss: 0.5510 - val_accuracy: 0.7919 - lr: 2.5000e-05 - 808s/epoch - 136ms/step
# Epoch 69/200
# 5964/5964 - 808s - loss: 0.6812 - accuracy: 0.7451 - val_loss: 0.5698 - val_accuracy: 0.7830 - lr: 2.5000e-05 - 808s/epoch - 136ms/step
# Epoch 70/200
# 5964/5964 - 802s - loss: 0.6794 - accuracy: 0.7442 - val_loss: 0.5555 - val_accuracy: 0.7899 - lr: 2.5000e-05 - 802s/epoch - 135ms/step
# Epoch 71/200
# 5964/5964 - 808s - loss: 0.6802 - accuracy: 0.7445 - val_loss: 0.5535 - val_accuracy: 0.7909 - lr: 2.5000e-05 - 808s/epoch - 136ms/step
# Epoch 72/200
# 5964/5964 - 806s - loss: 0.6786 - accuracy: 0.7454 - val_loss: 0.5528 - val_accuracy: 0.7907 - lr: 2.5000e-05 - 806s/epoch - 135ms/step
# Epoch 73/200
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 5964/5964 - 806s - loss: 0.6805 - accuracy: 0.7455 - val_loss: 0.5623 - val_accuracy: 0.7865 - lr: 2.5000e-05 - 806s/epoch - 135ms/step
# Epoch 74/200
# 5964/5964 - 811s - loss: 0.6699 - accuracy: 0.7495 - val_loss: 0.5557 - val_accuracy: 0.7889 - lr: 1.2500e-05 - 811s/epoch - 136ms/step
# Epoch 75/200
# 5964/5964 - 819s - loss: 0.6714 - accuracy: 0.7491 - val_loss: 0.5472 - val_accuracy: 0.7929 - lr: 1.2500e-05 - 819s/epoch - 137ms/step
# Epoch 76/200
# 5964/5964 - 808s - loss: 0.6712 - accuracy: 0.7483 - val_loss: 0.5553 - val_accuracy: 0.7900 - lr: 1.2500e-05 - 808s/epoch - 135ms/step
# Epoch 77/200
# 5964/5964 - 814s - loss: 0.6716 - accuracy: 0.7489 - val_loss: 0.5564 - val_accuracy: 0.7883 - lr: 1.2500e-05 - 814s/epoch - 137ms/step
# Epoch 78/200
# 5964/5964 - 800s - loss: 0.6718 - accuracy: 0.7481 - val_loss: 0.5497 - val_accuracy: 0.7920 - lr: 1.2500e-05 - 800s/epoch - 134ms/step
# Epoch 79/200
# 5964/5964 - 802s - loss: 0.6707 - accuracy: 0.7497 - val_loss: 0.5509 - val_accuracy: 0.7921 - lr: 1.2500e-05 - 802s/epoch - 134ms/step
# Epoch 80/200
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 5964/5964 - 808s - loss: 0.6698 - accuracy: 0.7490 - val_loss: 0.5566 - val_accuracy: 0.7898 - lr: 1.2500e-05 - 808s/epoch - 136ms/step
# Epoch 81/200
# 5964/5964 - 808s - loss: 0.6680 - accuracy: 0.7491 - val_loss: 0.5467 - val_accuracy: 0.7921 - lr: 6.2500e-06 - 808s/epoch - 135ms/step
# Epoch 82/200
# 5964/5964 - 801s - loss: 0.6685 - accuracy: 0.7504 - val_loss: 0.5503 - val_accuracy: 0.7919 - lr: 6.2500e-06 - 801s/epoch - 134ms/step
# Epoch 83/200
# 5964/5964 - 803s - loss: 0.6669 - accuracy: 0.7502 - val_loss: 0.5466 - val_accuracy: 0.7934 - lr: 6.2500e-06 - 803s/epoch - 135ms/step
# Epoch 84/200
# 5964/5964 - 801s - loss: 0.6654 - accuracy: 0.7494 - val_loss: 0.5464 - val_accuracy: 0.7930 - lr: 6.2500e-06 - 801s/epoch - 134ms/step
# Epoch 85/200
# 5964/5964 - 794s - loss: 0.6639 - accuracy: 0.7512 - val_loss: 0.5473 - val_accuracy: 0.7927 - lr: 6.2500e-06 - 794s/epoch - 133ms/step
# Epoch 86/200
# 5964/5964 - 802s - loss: 0.6640 - accuracy: 0.7508 - val_loss: 0.5470 - val_accuracy: 0.7921 - lr: 6.2500e-06 - 802s/epoch - 134ms/step
# Epoch 87/200
# 5964/5964 - 811s - loss: 0.6667 - accuracy: 0.7498 - val_loss: 0.5491 - val_accuracy: 0.7917 - lr: 6.2500e-06 - 811s/epoch - 136ms/step
# Epoch 88/200
# 5964/5964 - 799s - loss: 0.6653 - accuracy: 0.7506 - val_loss: 0.5430 - val_accuracy: 0.7948 - lr: 6.2500e-06 - 799s/epoch - 134ms/step
# Epoch 89/200
# 5964/5964 - 805s - loss: 0.6646 - accuracy: 0.7504 - val_loss: 0.5449 - val_accuracy: 0.7936 - lr: 6.2500e-06 - 805s/epoch - 135ms/step
# Epoch 90/200
# 5964/5964 - 807s - loss: 0.6655 - accuracy: 0.7511 - val_loss: 0.5527 - val_accuracy: 0.7902 - lr: 6.2500e-06 - 807s/epoch - 135ms/step
# Epoch 91/200
# 5964/5964 - 808s - loss: 0.6655 - accuracy: 0.7509 - val_loss: 0.5466 - val_accuracy: 0.7929 - lr: 6.2500e-06 - 808s/epoch - 135ms/step
# Epoch 92/200
# 5964/5964 - 807s - loss: 0.6647 - accuracy: 0.7510 - val_loss: 0.5465 - val_accuracy: 0.7923 - lr: 6.2500e-06 - 807s/epoch - 135ms/step
# Epoch 93/200
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5964/5964 - 809s - loss: 0.6640 - accuracy: 0.7511 - val_loss: 0.5453 - val_accuracy: 0.7935 - lr: 6.2500e-06 - 809s/epoch - 136ms/step
# Epoch 94/200
# 5964/5964 - 808s - loss: 0.6622 - accuracy: 0.7523 - val_loss: 0.5465 - val_accuracy: 0.7919 - lr: 3.1250e-06 - 808s/epoch - 135ms/step
# Epoch 95/200
# 5964/5964 - 806s - loss: 0.6631 - accuracy: 0.7515 - val_loss: 0.5483 - val_accuracy: 0.7918 - lr: 3.1250e-06 - 806s/epoch - 135ms/step
# Epoch 96/200
# 5964/5964 - 807s - loss: 0.6616 - accuracy: 0.7524 - val_loss: 0.5458 - val_accuracy: 0.7926 - lr: 3.1250e-06 - 807s/epoch - 135ms/step
# Epoch 97/200
# 5964/5964 - 805s - loss: 0.6642 - accuracy: 0.7520 - val_loss: 0.5469 - val_accuracy: 0.7924 - lr: 3.1250e-06 - 805s/epoch - 135ms/step
# Epoch 98/200
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 5964/5964 - 811s - loss: 0.6637 - accuracy: 0.7527 - val_loss: 0.5498 - val_accuracy: 0.7910 - lr: 3.1250e-06 - 811s/epoch - 136ms/step
# end

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\cwt_all_std_force_quality\Conv2D_transfer.h5', save_format="h5")

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict(val_generator)
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    df_val["case"],
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN2D_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 135s 90ms/step

# %%
_, accuracy = model.evaluate(val_generator)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 137s 92ms/step - loss: 0.5430 - accuracy: 0.7948
# Test accuracy: 79.48%
