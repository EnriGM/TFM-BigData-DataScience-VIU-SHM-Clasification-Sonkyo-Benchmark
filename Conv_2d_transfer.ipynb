# %%
import tensorflow as tf
import sklearn
import pandas as pd
from tensorflow.keras import layers, models
from tensorflow import keras
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
tf.random.set_seed(42)
img_directory = r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale"
df = pd.read_csv(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale_case_temp_info.csv",
                header=0, index_col=0)

lb = LabelEncoder()
df["case"] = lb.fit_transform(df["case"])

sc = StandardScaler()
df["temperature"] = sc.fit_transform(df["temperature"].values.reshape(-1, 1))

df_train, df_val = sklearn.model_selection.train_test_split(df, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import math
import os

class CustomDataGenerator(tf.keras.utils.Sequence):

    ''' Custom DataGenerator to load img 
    
    Arguments:
        data_frame = pandas data frame in filenames and labels format
        batch_size = divide data in batches
        shuffle = shuffle data before loading
        img_shape = image shape in (h, w, d) format
        augmentation = data augmentation to make model rebust to overfitting
    
    Output:
        Img: numpy array of image
        label : output label for image
    '''
    
    def __init__(self, data_frame, batch_size=10, img_shape=None, augmentation=True, num_classes=None, folder=""):
        self.data_frame = data_frame
        self.train_len = len(data_frame)
        self.batch_size = batch_size
        self.img_shape = img_shape
        self.num_classes = num_classes
        self.folder = folder
        print(f"Found {self.data_frame.shape[0]} images belonging to {self.num_classes} classes")

    def __len__(self):
        ''' return total number of batches '''
        #self.data_frame = shuffle(self.data_frame)
        return math.ceil(self.train_len/self.batch_size)

    def on_epoch_end(self):
        ''' shuffle data after every epoch '''
        # fix on epoch end it's not working, adding shuffle in len for alternative
        pass
    
    def __data_augmentation(self, img):
        ''' function for apply some data augmentation '''
        img = img/255
        return img
        
    def __get_image(self, file_id):
        """ open image with file_id path and apply data augmentation """
        img = Image.open(os.path.join(self.folder, file_id))
        img = img.resize(self.img_shape, Image.Resampling.LANCZOS)
        img = img.convert("RGB")
        img = tf.keras.preprocessing.image.img_to_array(img) # /255 removed for EfficientNetV2B0
        img = tf.convert_to_tensor(img)
        return img

    def __get_label(self, label_id):
        """ uncomment the below line to convert label into categorical format """
        label_id = tf.keras.utils.to_categorical(label_id, self.num_classes)
        label_id = tf.convert_to_tensor(label_id)
        return label_id

    def __get_temp(self, temp):
        return temp
    
    def __getitem__(self, idx):
        batch_x = self.data_frame["filename"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.data_frame["case"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_temp = self.data_frame["temperature"][idx * self.batch_size:(idx + 1) * self.batch_size]
        # read your data here using the batch lists, batch_x and batch_y
        x = [self.__get_image(file_id) for file_id in batch_x] 
        y = [self.__get_label(label_id) for label_id in batch_y]
        temp = np.array([self.__get_temp(temp) for temp in batch_temp]).T
        data = tf.stack(x)
        label =  tf.stack(y)
        return [data, temp], label

train_generator = CustomDataGenerator(df_train, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
val_generator = CustomDataGenerator(df_val, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
# Out:
# Found 190847 images belonging to 13 classes
# Found 47712 images belonging to 13 classes

# %%
from tensorflow.keras.applications import EfficientNetV2B0
img_input = layers.Input(shape=(224, 224, 3))
temp_input = layers.Input(shape=(1,))

#Transfer learning model
base_model = EfficientNetV2B0(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

base_model.trainable = False  # Congelamos el modelo base

x = base_model(img_input)

gap = layers.GlobalAveragePooling2D()(x)

dense_gap = layers.Dense(128, activation='relu')(gap)
dense_temp = layers.Dense(1, activation="relu")(temp_input)

merged = layers.Concatenate(axis=1)([dense_gap, dense_temp])

dense_1 = layers.Dense(128, activation='relu')(merged)
drop_1 = layers.Dropout(0.2)(dense_1)
dense_2 = layers.Dense(64, activation='relu')(drop_1)
drop_2 = layers.Dropout(0.2)(dense_2)
output = layers.Dense(13, activation='softmax')(drop_2)

model = models.Model(inputs=[img_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  efficientnetv2-b0 (Functional)  (None, 7, 7, 1280)  5919312     ['input_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['efficientnetv2-b0[0][0]']
#  alAveragePooling2D)
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  dense (Dense)                  (None, 128)          163968      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 129)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16640       ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 13)           845         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 6,109,023
# Trainable params: 189,711
# Non-trainable params: 5,919,312
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=["categorical_crossentropy"],
    metrics=['accuracy']
)

# %%
num_epochs = 200

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1)

# Fit the model.

history = model.fit(
    x=train_generator,
    validation_data=val_generator,
    epochs=num_epochs,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
print("end")
# Out:
# Epoch 1/200
# 5964/5964 - 766s - loss: 1.7879 - accuracy: 0.3677 - val_loss: 1.3283 - val_accuracy: 0.5193 - lr: 1.0000e-04 - 766s/epoch - 129ms/step
# Epoch 2/200
# 5964/5964 - 751s - loss: 1.3699 - accuracy: 0.4904 - val_loss: 1.1267 - val_accuracy: 0.5778 - lr: 1.0000e-04 - 751s/epoch - 126ms/step
# Epoch 3/200
# 5964/5964 - 759s - loss: 1.2243 - accuracy: 0.5395 - val_loss: 0.9999 - val_accuracy: 0.6249 - lr: 1.0000e-04 - 759s/epoch - 127ms/step
# Epoch 4/200
# 5964/5964 - 760s - loss: 1.1444 - accuracy: 0.5687 - val_loss: 0.9307 - val_accuracy: 0.6489 - lr: 1.0000e-04 - 760s/epoch - 128ms/step
# Epoch 5/200
# 5964/5964 - 761s - loss: 1.0874 - accuracy: 0.5885 - val_loss: 0.8876 - val_accuracy: 0.6656 - lr: 1.0000e-04 - 761s/epoch - 128ms/step
# Epoch 6/200
# 5964/5964 - 768s - loss: 1.0411 - accuracy: 0.6063 - val_loss: 0.8415 - val_accuracy: 0.6797 - lr: 1.0000e-04 - 768s/epoch - 129ms/step
# Epoch 7/200
# 5964/5964 - 752s - loss: 1.0086 - accuracy: 0.6187 - val_loss: 0.8556 - val_accuracy: 0.6711 - lr: 1.0000e-04 - 752s/epoch - 126ms/step
# Epoch 8/200
# 5964/5964 - 760s - loss: 0.9833 - accuracy: 0.6268 - val_loss: 0.7942 - val_accuracy: 0.6962 - lr: 1.0000e-04 - 760s/epoch - 127ms/step
# Epoch 9/200
# 5964/5964 - 757s - loss: 0.9597 - accuracy: 0.6372 - val_loss: 0.7855 - val_accuracy: 0.7000 - lr: 1.0000e-04 - 757s/epoch - 127ms/step
# Epoch 10/200
# 5964/5964 - 763s - loss: 0.9415 - accuracy: 0.6445 - val_loss: 0.7787 - val_accuracy: 0.7007 - lr: 1.0000e-04 - 763s/epoch - 128ms/step
# Epoch 11/200
# 5964/5964 - 765s - loss: 0.9246 - accuracy: 0.6512 - val_loss: 0.7947 - val_accuracy: 0.6902 - lr: 1.0000e-04 - 765s/epoch - 128ms/step
# Epoch 12/200
# 5964/5964 - 756s - loss: 0.9110 - accuracy: 0.6547 - val_loss: 0.7422 - val_accuracy: 0.7160 - lr: 1.0000e-04 - 756s/epoch - 127ms/step
# Epoch 13/200
# 5964/5964 - 761s - loss: 0.8978 - accuracy: 0.6603 - val_loss: 0.7399 - val_accuracy: 0.7162 - lr: 1.0000e-04 - 761s/epoch - 128ms/step
# Epoch 14/200
# 5964/5964 - 763s - loss: 0.8852 - accuracy: 0.6632 - val_loss: 0.7410 - val_accuracy: 0.7170 - lr: 1.0000e-04 - 763s/epoch - 128ms/step
# Epoch 15/200
# 5964/5964 - 750s - loss: 0.8752 - accuracy: 0.6694 - val_loss: 0.7365 - val_accuracy: 0.7187 - lr: 1.0000e-04 - 750s/epoch - 126ms/step
# Epoch 16/200
# 5964/5964 - 754s - loss: 0.8674 - accuracy: 0.6727 - val_loss: 0.7790 - val_accuracy: 0.7016 - lr: 1.0000e-04 - 754s/epoch - 126ms/step
# Epoch 17/200
# 5964/5964 - 751s - loss: 0.8576 - accuracy: 0.6764 - val_loss: 0.7075 - val_accuracy: 0.7323 - lr: 1.0000e-04 - 751s/epoch - 126ms/step
# Epoch 18/200
# 5964/5964 - 772s - loss: 0.8492 - accuracy: 0.6792 - val_loss: 0.7974 - val_accuracy: 0.6905 - lr: 1.0000e-04 - 772s/epoch - 129ms/step
# Epoch 19/200
# 5964/5964 - 763s - loss: 0.8396 - accuracy: 0.6832 - val_loss: 0.6963 - val_accuracy: 0.7303 - lr: 1.0000e-04 - 763s/epoch - 128ms/step
# Epoch 20/200
# 5964/5964 - 751s - loss: 0.8345 - accuracy: 0.6846 - val_loss: 0.8335 - val_accuracy: 0.6841 - lr: 1.0000e-04 - 751s/epoch - 126ms/step
# Epoch 21/200
# 5964/5964 - 751s - loss: 0.8280 - accuracy: 0.6881 - val_loss: 0.6758 - val_accuracy: 0.7428 - lr: 1.0000e-04 - 751s/epoch - 126ms/step
# Epoch 22/200
# Epoch 53/200
# 5964/5964 - 774s - loss: 0.7195 - accuracy: 0.7291 - val_loss: 0.5793 - val_accuracy: 0.7816 - lr: 5.0000e-05 - 774s/epoch - 130ms/step
# Epoch 54/200
# 5964/5964 - 774s - loss: 0.7151 - accuracy: 0.7320 - val_loss: 0.5910 - val_accuracy: 0.7749 - lr: 5.0000e-05 - 774s/epoch - 130ms/step
# Epoch 55/200
# 5964/5964 - 770s - loss: 0.7155 - accuracy: 0.7305 - val_loss: 0.5778 - val_accuracy: 0.7800 - lr: 5.0000e-05 - 770s/epoch - 129ms/step
# Epoch 56/200
# 5964/5964 - 766s - loss: 0.7138 - accuracy: 0.7320 - val_loss: 0.6018 - val_accuracy: 0.7715 - lr: 5.0000e-05 - 766s/epoch - 128ms/step
# Epoch 57/200
# 5964/5964 - 777s - loss: 0.7118 - accuracy: 0.7322 - val_loss: 0.5814 - val_accuracy: 0.7803 - lr: 5.0000e-05 - 777s/epoch - 130ms/step
# Epoch 58/200
# 5964/5964 - 772s - loss: 0.7127 - accuracy: 0.7329 - val_loss: 0.5812 - val_accuracy: 0.7789 - lr: 5.0000e-05 - 772s/epoch - 129ms/step
# Epoch 59/200
# 5964/5964 - 777s - loss: 0.7084 - accuracy: 0.7335 - val_loss: 0.5768 - val_accuracy: 0.7825 - lr: 5.0000e-05 - 777s/epoch - 130ms/step
# Epoch 60/200
# 5964/5964 - 772s - loss: 0.7087 - accuracy: 0.7344 - val_loss: 0.5995 - val_accuracy: 0.7744 - lr: 5.0000e-05 - 772s/epoch - 129ms/step
# Epoch 61/200
# 5964/5964 - 773s - loss: 0.7077 - accuracy: 0.7342 - val_loss: 0.5786 - val_accuracy: 0.7802 - lr: 5.0000e-05 - 773s/epoch - 130ms/step
# Epoch 62/200
# 5964/5964 - 771s - loss: 0.7059 - accuracy: 0.7361 - val_loss: 0.5738 - val_accuracy: 0.7824 - lr: 5.0000e-05 - 771s/epoch - 129ms/step
# Epoch 63/200
# 5964/5964 - 768s - loss: 0.7048 - accuracy: 0.7363 - val_loss: 0.5684 - val_accuracy: 0.7845 - lr: 5.0000e-05 - 768s/epoch - 129ms/step
# Epoch 64/200
# 5964/5964 - 778s - loss: 0.7048 - accuracy: 0.7355 - val_loss: 0.5706 - val_accuracy: 0.7843 - lr: 5.0000e-05 - 778s/epoch - 130ms/step
# Epoch 65/200
# 5964/5964 - 780s - loss: 0.7037 - accuracy: 0.7363 - val_loss: 0.5808 - val_accuracy: 0.7787 - lr: 5.0000e-05 - 780s/epoch - 131ms/step
# Epoch 66/200
# 5964/5964 - 776s - loss: 0.7005 - accuracy: 0.7379 - val_loss: 0.5806 - val_accuracy: 0.7819 - lr: 5.0000e-05 - 776s/epoch - 130ms/step
# Epoch 67/200
# 5964/5964 - 777s - loss: 0.7000 - accuracy: 0.7375 - val_loss: 0.5689 - val_accuracy: 0.7863 - lr: 5.0000e-05 - 777s/epoch - 130ms/step
# Epoch 68/200
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# 5964/5964 - 801s - loss: 0.6573 - accuracy: 0.7540 - val_loss: 0.5365 - val_accuracy: 0.7990 - lr: 1.5625e-06 - 801s/epoch - 134ms/step
# Epoch 114/200
# 5964/5964 - 804s - loss: 0.6568 - accuracy: 0.7547 - val_loss: 0.5387 - val_accuracy: 0.7984 - lr: 1.5625e-06 - 804s/epoch - 135ms/step
# Epoch 115/200
# 5964/5964 - 801s - loss: 0.6577 - accuracy: 0.7528 - val_loss: 0.5375 - val_accuracy: 0.7984 - lr: 1.5625e-06 - 801s/epoch - 134ms/step
# Epoch 116/200
# 5964/5964 - 800s - loss: 0.6581 - accuracy: 0.7533 - val_loss: 0.5399 - val_accuracy: 0.7969 - lr: 1.5625e-06 - 800s/epoch - 134ms/step
# Epoch 117/200
# 5964/5964 - 807s - loss: 0.6550 - accuracy: 0.7555 - val_loss: 0.5370 - val_accuracy: 0.7977 - lr: 1.5625e-06 - 807s/epoch - 135ms/step
# Epoch 118/200
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 1e-06.
# 5964/5964 - 803s - loss: 0.6562 - accuracy: 0.7543 - val_loss: 0.5367 - val_accuracy: 0.7981 - lr: 1.5625e-06 - 803s/epoch - 135ms/step
# Epoch 119/200
# 5964/5964 - 804s - loss: 0.6544 - accuracy: 0.7542 - val_loss: 0.5388 - val_accuracy: 0.7973 - lr: 1.0000e-06 - 804s/epoch - 135ms/step
# Epoch 120/200
# 5964/5964 - 803s - loss: 0.6571 - accuracy: 0.7543 - val_loss: 0.5367 - val_accuracy: 0.7986 - lr: 1.0000e-06 - 803s/epoch - 135ms/step
# Epoch 121/200
# 5964/5964 - 810s - loss: 0.6563 - accuracy: 0.7534 - val_loss: 0.5375 - val_accuracy: 0.7973 - lr: 1.0000e-06 - 810s/epoch - 136ms/step
# Epoch 122/200
# 5964/5964 - 803s - loss: 0.6545 - accuracy: 0.7544 - val_loss: 0.5386 - val_accuracy: 0.7974 - lr: 1.0000e-06 - 803s/epoch - 135ms/step
# Epoch 123/200
# 5964/5964 - 813s - loss: 0.6581 - accuracy: 0.7525 - val_loss: 0.5366 - val_accuracy: 0.7984 - lr: 1.0000e-06 - 813s/epoch - 136ms/step
# end

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\cwt_all_std_force_quality\Conv2D_transfer.h5', save_format="h5")

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict(val_generator)
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    df_val["case"],
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN2D_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 135s 90ms/step

# %%
_, accuracy = model.evaluate(val_generator)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 142s 95ms/step - loss: 0.5365 - accuracy: 0.7990
# Test accuracy: 79.9%
