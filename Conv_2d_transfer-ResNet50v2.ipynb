# %%
import tensorflow as tf
import sklearn
import pandas as pd
from tensorflow.keras import layers, models
from tensorflow import keras
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
tf.random.set_seed(42)
img_directory = r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale"
df = pd.read_csv(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\cwt\cwt_no_comon_scale_case_temp_info.csv",
                header=0, index_col=0)

lb = LabelEncoder()
df["case"] = lb.fit_transform(df["case"])

sc = StandardScaler()
df["temperature"] = sc.fit_transform(df["temperature"].values.reshape(-1, 1))

df_train, df_val = sklearn.model_selection.train_test_split(df, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import math
import os

class CustomDataGenerator(tf.keras.utils.Sequence):

    ''' Custom DataGenerator to load img 
    
    Arguments:
        data_frame = pandas data frame in filenames and labels format
        batch_size = divide data in batches
        shuffle = shuffle data before loading
        img_shape = image shape in (h, w, d) format
        augmentation = data augmentation to make model rebust to overfitting
    
    Output:
        Img: numpy array of image
        label : output label for image
    '''
    
    def __init__(self, data_frame, batch_size=10, img_shape=None, augmentation=True, num_classes=None, folder=""):
        self.data_frame = data_frame
        self.train_len = len(data_frame)
        self.batch_size = batch_size
        self.img_shape = img_shape
        self.num_classes = num_classes
        self.folder = folder
        print(f"Found {self.data_frame.shape[0]} images belonging to {self.num_classes} classes")

    def __len__(self):
        ''' return total number of batches '''
        #self.data_frame = shuffle(self.data_frame)
        return math.ceil(self.train_len/self.batch_size)

    def on_epoch_end(self):
        ''' shuffle data after every epoch '''
        # fix on epoch end it's not working, adding shuffle in len for alternative
        pass
    
    def __data_augmentation(self, img):
        ''' function for apply some data augmentation '''
        img = img
        return img
        
    def __get_image(self, file_id):
        """ open image with file_id path and apply data augmentation """
        img = Image.open(os.path.join(self.folder, file_id))
        img = img.resize(self.img_shape, Image.Resampling.LANCZOS)
        img = img.convert("RGB")
        img = tf.keras.preprocessing.image.img_to_array(img) 
        img = tf.convert_to_tensor(img)
        img = keras.applications.resnet_v2.preprocess_input(img)
        return img

    def __get_label(self, label_id):
        """ uncomment the below line to convert label into categorical format """
        label_id = tf.keras.utils.to_categorical(label_id, self.num_classes)
        label_id = tf.convert_to_tensor(label_id)
        return label_id

    def __get_temp(self, temp):
        return temp
    
    def __getitem__(self, idx):
        batch_x = self.data_frame["filename"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.data_frame["case"][idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_temp = self.data_frame["temperature"][idx * self.batch_size:(idx + 1) * self.batch_size]
        # read your data here using the batch lists, batch_x and batch_y
        x = [self.__get_image(file_id) for file_id in batch_x] 
        y = [self.__get_label(label_id) for label_id in batch_y]
        temp = np.array([self.__get_temp(temp) for temp in batch_temp]).T
        data = tf.stack(x)
        label =  tf.stack(y)
        return [data, temp], label

train_generator = CustomDataGenerator(df_train, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
val_generator = CustomDataGenerator(df_val, batch_size=32, img_shape=(224, 224), augmentation=True, num_classes=13, folder=img_directory)
# Out:
# Found 190847 images belonging to 13 classes
# Found 47712 images belonging to 13 classes

# %%
from tensorflow.keras.applications import ResNet50V2
img_input = layers.Input(shape=(224, 224, 3))
temp_input = layers.Input(shape=(1,))

#Transfer learning model
base_model = ResNet50V2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

base_model.trainable = False  # Congelamos el modelo base

x = base_model(img_input)

gap = layers.GlobalAveragePooling2D()(x)

dense_gap = layers.Dense(128, activation='relu')(gap)
dense_temp = layers.Dense(1, activation="relu")(temp_input)

merged = layers.Concatenate(axis=1)([dense_gap, dense_temp])

dense_1 = layers.Dense(128, activation='relu')(merged)
drop_1 = layers.Dropout(0.2)(dense_1)
dense_2 = layers.Dense(64, activation='relu')(drop_1)
drop_2 = layers.Dropout(0.2)(dense_2)
output = layers.Dense(13, activation='softmax')(drop_2)

model = models.Model(inputs=[img_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  resnet50v2 (Functional)        (None, 7, 7, 2048)   23564800    ['input_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['resnet50v2[0][0]']
#  alAveragePooling2D)
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  dense (Dense)                  (None, 128)          262272      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 129)          0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16640       ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 13)           845         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23,852,815
# Trainable params: 288,015
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=["categorical_crossentropy"],
    metrics=['accuracy']
)

# %%
num_epochs = 200

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1)

# Fit the model.

history = model.fit(
    x=train_generator,
    validation_data=val_generator,
    epochs=num_epochs,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
print("end")
# Out:
# Epoch 1/200
# 5964/5964 - 946s - loss: 1.8112 - accuracy: 0.3591 - val_loss: 1.4791 - val_accuracy: 0.4634 - lr: 1.0000e-04 - 946s/epoch - 159ms/step
# Epoch 2/200
# 5964/5964 - 925s - loss: 1.4618 - accuracy: 0.4600 - val_loss: 1.3195 - val_accuracy: 0.5152 - lr: 1.0000e-04 - 925s/epoch - 155ms/step
# Epoch 3/200
# 5964/5964 - 927s - loss: 1.3310 - accuracy: 0.5065 - val_loss: 1.2207 - val_accuracy: 0.5446 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 4/200
# 5964/5964 - 931s - loss: 1.2474 - accuracy: 0.5352 - val_loss: 1.1503 - val_accuracy: 0.5702 - lr: 1.0000e-04 - 931s/epoch - 156ms/step
# Epoch 5/200
# 5964/5964 - 930s - loss: 1.1922 - accuracy: 0.5543 - val_loss: 1.1063 - val_accuracy: 0.5862 - lr: 1.0000e-04 - 930s/epoch - 156ms/step
# Epoch 6/200
# 5964/5964 - 922s - loss: 1.1535 - accuracy: 0.5687 - val_loss: 1.1026 - val_accuracy: 0.5880 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 7/200
# 5964/5964 - 930s - loss: 1.1230 - accuracy: 0.5802 - val_loss: 1.0537 - val_accuracy: 0.6027 - lr: 1.0000e-04 - 930s/epoch - 156ms/step
# Epoch 8/200
# 5964/5964 - 922s - loss: 1.0994 - accuracy: 0.5888 - val_loss: 1.0427 - val_accuracy: 0.6075 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 9/200
# 5964/5964 - 922s - loss: 1.0786 - accuracy: 0.5965 - val_loss: 1.0232 - val_accuracy: 0.6159 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 10/200
# 5964/5964 - 924s - loss: 1.0605 - accuracy: 0.6030 - val_loss: 1.0306 - val_accuracy: 0.6133 - lr: 1.0000e-04 - 924s/epoch - 155ms/step
# Epoch 11/200
# 5964/5964 - 925s - loss: 1.0460 - accuracy: 0.6094 - val_loss: 1.0050 - val_accuracy: 0.6196 - lr: 1.0000e-04 - 925s/epoch - 155ms/step
# Epoch 12/200
# 5964/5964 - 922s - loss: 1.0312 - accuracy: 0.6150 - val_loss: 1.0021 - val_accuracy: 0.6227 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 13/200
# 5964/5964 - 922s - loss: 1.0197 - accuracy: 0.6182 - val_loss: 0.9793 - val_accuracy: 0.6313 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 14/200
# 5964/5964 - 924s - loss: 1.0093 - accuracy: 0.6220 - val_loss: 0.9803 - val_accuracy: 0.6314 - lr: 1.0000e-04 - 924s/epoch - 155ms/step
# Epoch 15/200
# 5964/5964 - 924s - loss: 0.9967 - accuracy: 0.6270 - val_loss: 0.9734 - val_accuracy: 0.6335 - lr: 1.0000e-04 - 924s/epoch - 155ms/step
# Epoch 16/200
# 5964/5964 - 922s - loss: 0.9895 - accuracy: 0.6307 - val_loss: 0.9671 - val_accuracy: 0.6370 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 17/200
# 5964/5964 - 927s - loss: 0.9816 - accuracy: 0.6334 - val_loss: 0.9553 - val_accuracy: 0.6418 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 18/200
# 5964/5964 - 922s - loss: 0.9738 - accuracy: 0.6351 - val_loss: 0.9581 - val_accuracy: 0.6395 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 19/200
# 5964/5964 - 930s - loss: 0.9665 - accuracy: 0.6389 - val_loss: 0.9572 - val_accuracy: 0.6395 - lr: 1.0000e-04 - 930s/epoch - 156ms/step
# Epoch 20/200
# 5964/5964 - 924s - loss: 0.9607 - accuracy: 0.6409 - val_loss: 0.9520 - val_accuracy: 0.6427 - lr: 1.0000e-04 - 924s/epoch - 155ms/step
# Epoch 21/200
# 5964/5964 - 923s - loss: 0.9511 - accuracy: 0.6445 - val_loss: 0.9559 - val_accuracy: 0.6410 - lr: 1.0000e-04 - 923s/epoch - 155ms/step
# Epoch 22/200
# 5964/5964 - 923s - loss: 0.9473 - accuracy: 0.6459 - val_loss: 0.9434 - val_accuracy: 0.6464 - lr: 1.0000e-04 - 923s/epoch - 155ms/step
# Epoch 23/200
# 5964/5964 - 934s - loss: 0.9405 - accuracy: 0.6481 - val_loss: 0.9420 - val_accuracy: 0.6481 - lr: 1.0000e-04 - 934s/epoch - 157ms/step
# Epoch 24/200
# 5964/5964 - 926s - loss: 0.9346 - accuracy: 0.6503 - val_loss: 0.9369 - val_accuracy: 0.6480 - lr: 1.0000e-04 - 926s/epoch - 155ms/step
# Epoch 25/200
# 5964/5964 - 926s - loss: 0.9295 - accuracy: 0.6520 - val_loss: 0.9741 - val_accuracy: 0.6338 - lr: 1.0000e-04 - 926s/epoch - 155ms/step
# Epoch 26/200
# 5964/5964 - 931s - loss: 0.9242 - accuracy: 0.6545 - val_loss: 0.9258 - val_accuracy: 0.6537 - lr: 1.0000e-04 - 931s/epoch - 156ms/step
# Epoch 27/200
# 5964/5964 - 923s - loss: 0.9180 - accuracy: 0.6561 - val_loss: 0.9327 - val_accuracy: 0.6502 - lr: 1.0000e-04 - 923s/epoch - 155ms/step
# Epoch 28/200
# 5964/5964 - 927s - loss: 0.9154 - accuracy: 0.6583 - val_loss: 0.9436 - val_accuracy: 0.6466 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 29/200
# 5964/5964 - 931s - loss: 0.9099 - accuracy: 0.6603 - val_loss: 0.9506 - val_accuracy: 0.6446 - lr: 1.0000e-04 - 931s/epoch - 156ms/step
# Epoch 30/200
# 5964/5964 - 922s - loss: 0.9065 - accuracy: 0.6611 - val_loss: 0.9200 - val_accuracy: 0.6556 - lr: 1.0000e-04 - 922s/epoch - 155ms/step
# Epoch 31/200
# 5964/5964 - 927s - loss: 0.9026 - accuracy: 0.6626 - val_loss: 0.9462 - val_accuracy: 0.6474 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 32/200
# 5964/5964 - 931s - loss: 0.8958 - accuracy: 0.6657 - val_loss: 0.9288 - val_accuracy: 0.6546 - lr: 1.0000e-04 - 931s/epoch - 156ms/step
# Epoch 33/200
# 5964/5964 - 927s - loss: 0.8936 - accuracy: 0.6675 - val_loss: 0.9274 - val_accuracy: 0.6554 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 34/200
# 5964/5964 - 924s - loss: 0.8908 - accuracy: 0.6669 - val_loss: 0.9078 - val_accuracy: 0.6613 - lr: 1.0000e-04 - 924s/epoch - 155ms/step
# Epoch 35/200
# 5964/5964 - 932s - loss: 0.8857 - accuracy: 0.6706 - val_loss: 0.9076 - val_accuracy: 0.6601 - lr: 1.0000e-04 - 932s/epoch - 156ms/step
# Epoch 36/200
# 5964/5964 - 927s - loss: 0.8826 - accuracy: 0.6700 - val_loss: 0.9148 - val_accuracy: 0.6586 - lr: 1.0000e-04 - 927s/epoch - 155ms/step
# Epoch 37/200
# 5964/5964 - 930s - loss: 0.8783 - accuracy: 0.6719 - val_loss: 0.9230 - val_accuracy: 0.6545 - lr: 1.0000e-04 - 930s/epoch - 156ms/step
# Epoch 38/200
# 5964/5964 - 930s - loss: 0.8767 - accuracy: 0.6729 - val_loss: 0.9255 - val_accuracy: 0.6524 - lr: 1.0000e-04 - 930s/epoch - 156ms/step
# Epoch 39/200
# 5964/5964 - 928s - loss: 0.8720 - accuracy: 0.6737 - val_loss: 0.9301 - val_accuracy: 0.6551 - lr: 1.0000e-04 - 928s/epoch - 156ms/step
# Epoch 40/200
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 5964/5964 - 925s - loss: 0.8706 - accuracy: 0.6753 - val_loss: 0.9188 - val_accuracy: 0.6589 - lr: 1.0000e-04 - 925s/epoch - 155ms/step
# Epoch 41/200
# 5964/5964 - 929s - loss: 0.8417 - accuracy: 0.6859 - val_loss: 0.9065 - val_accuracy: 0.6648 - lr: 5.0000e-05 - 929s/epoch - 156ms/step
# Epoch 42/200
# 5964/5964 - 929s - loss: 0.8392 - accuracy: 0.6863 - val_loss: 0.9032 - val_accuracy: 0.6628 - lr: 5.0000e-05 - 929s/epoch - 156ms/step
# Epoch 43/200
# 5964/5964 - 930s - loss: 0.8360 - accuracy: 0.6880 - val_loss: 0.9080 - val_accuracy: 0.6626 - lr: 5.0000e-05 - 930s/epoch - 156ms/step
# Epoch 44/200
# 5964/5964 - 935s - loss: 0.8347 - accuracy: 0.6877 - val_loss: 0.9132 - val_accuracy: 0.6622 - lr: 5.0000e-05 - 935s/epoch - 157ms/step
# Epoch 45/200
# 5964/5964 - 931s - loss: 0.8328 - accuracy: 0.6887 - val_loss: 0.9192 - val_accuracy: 0.6594 - lr: 5.0000e-05 - 931s/epoch - 156ms/step
# Epoch 46/200
# 5964/5964 - 933s - loss: 0.8299 - accuracy: 0.6899 - val_loss: 0.8994 - val_accuracy: 0.6660 - lr: 5.0000e-05 - 933s/epoch - 156ms/step
# Epoch 47/200
# 5964/5964 - 935s - loss: 0.8293 - accuracy: 0.6906 - val_loss: 0.9038 - val_accuracy: 0.6622 - lr: 5.0000e-05 - 935s/epoch - 157ms/step
# Epoch 48/200
# 5964/5964 - 929s - loss: 0.8262 - accuracy: 0.6913 - val_loss: 0.9056 - val_accuracy: 0.6654 - lr: 5.0000e-05 - 929s/epoch - 156ms/step
# Epoch 49/200
# 5964/5964 - 931s - loss: 0.8257 - accuracy: 0.6925 - val_loss: 0.9028 - val_accuracy: 0.6647 - lr: 5.0000e-05 - 931s/epoch - 156ms/step
# Epoch 50/200
# 5964/5964 - 933s - loss: 0.8240 - accuracy: 0.6923 - val_loss: 0.9027 - val_accuracy: 0.6654 - lr: 5.0000e-05 - 933s/epoch - 156ms/step
# Epoch 51/200
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 5964/5964 - 918s - loss: 0.8230 - accuracy: 0.6931 - val_loss: 0.9068 - val_accuracy: 0.6658 - lr: 5.0000e-05 - 918s/epoch - 154ms/step
# Epoch 52/200
# 5964/5964 - 930s - loss: 0.8066 - accuracy: 0.6996 - val_loss: 0.9023 - val_accuracy: 0.6675 - lr: 2.5000e-05 - 930s/epoch - 156ms/step
# Epoch 53/200
# 5964/5964 - 936s - loss: 0.8067 - accuracy: 0.6986 - val_loss: 0.9033 - val_accuracy: 0.6662 - lr: 2.5000e-05 - 936s/epoch - 157ms/step
# Epoch 54/200
# 5964/5964 - 929s - loss: 0.8043 - accuracy: 0.7009 - val_loss: 0.9019 - val_accuracy: 0.6683 - lr: 2.5000e-05 - 929s/epoch - 156ms/step
# Epoch 55/200
# 5964/5964 - 928s - loss: 0.8053 - accuracy: 0.6991 - val_loss: 0.9018 - val_accuracy: 0.6671 - lr: 2.5000e-05 - 928s/epoch - 156ms/step
# Epoch 56/200
# 5964/5964 - 933s - loss: 0.8006 - accuracy: 0.7012 - val_loss: 0.8993 - val_accuracy: 0.6686 - lr: 2.5000e-05 - 933s/epoch - 156ms/step
# Epoch 57/200
# 5964/5964 - 936s - loss: 0.8011 - accuracy: 0.7018 - val_loss: 0.9093 - val_accuracy: 0.6653 - lr: 2.5000e-05 - 936s/epoch - 157ms/step
# Epoch 58/200
# 5964/5964 - 930s - loss: 0.8001 - accuracy: 0.7022 - val_loss: 0.8998 - val_accuracy: 0.6674 - lr: 2.5000e-05 - 930s/epoch - 156ms/step
# Epoch 59/200
# 5964/5964 - 936s - loss: 0.7996 - accuracy: 0.7014 - val_loss: 0.9042 - val_accuracy: 0.6660 - lr: 2.5000e-05 - 936s/epoch - 157ms/step
# Epoch 60/200
# 5964/5964 - 931s - loss: 0.7978 - accuracy: 0.7026 - val_loss: 0.9032 - val_accuracy: 0.6677 - lr: 2.5000e-05 - 931s/epoch - 156ms/step
# Epoch 61/200
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 5964/5964 - 930s - loss: 0.7977 - accuracy: 0.7027 - val_loss: 0.9053 - val_accuracy: 0.6670 - lr: 2.5000e-05 - 930s/epoch - 156ms/step
# Epoch 62/200
# 5964/5964 - 935s - loss: 0.7914 - accuracy: 0.7049 - val_loss: 0.9002 - val_accuracy: 0.6688 - lr: 1.2500e-05 - 935s/epoch - 157ms/step
# Epoch 63/200
# 5964/5964 - 931s - loss: 0.7893 - accuracy: 0.7061 - val_loss: 0.8986 - val_accuracy: 0.6689 - lr: 1.2500e-05 - 931s/epoch - 156ms/step
# Epoch 64/200
# 5964/5964 - 931s - loss: 0.7871 - accuracy: 0.7058 - val_loss: 0.8999 - val_accuracy: 0.6686 - lr: 1.2500e-05 - 931s/epoch - 156ms/step
# Epoch 65/200
# 5964/5964 - 940s - loss: 0.7883 - accuracy: 0.7051 - val_loss: 0.9008 - val_accuracy: 0.6684 - lr: 1.2500e-05 - 940s/epoch - 158ms/step
# Epoch 66/200
# 5964/5964 - 932s - loss: 0.7872 - accuracy: 0.7064 - val_loss: 0.9014 - val_accuracy: 0.6686 - lr: 1.2500e-05 - 932s/epoch - 156ms/step
# Epoch 67/200
# 5964/5964 - 936s - loss: 0.7853 - accuracy: 0.7075 - val_loss: 0.9017 - val_accuracy: 0.6682 - lr: 1.2500e-05 - 936s/epoch - 157ms/step
# Epoch 68/200
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 5964/5964 - 939s - loss: 0.7858 - accuracy: 0.7075 - val_loss: 0.9006 - val_accuracy: 0.6678 - lr: 1.2500e-05 - 939s/epoch - 157ms/step
# Epoch 69/200
# 5964/5964 - 939s - loss: 0.7826 - accuracy: 0.7078 - val_loss: 0.8999 - val_accuracy: 0.6692 - lr: 6.2500e-06 - 939s/epoch - 157ms/step
# Epoch 70/200
# 5964/5964 - 934s - loss: 0.7817 - accuracy: 0.7093 - val_loss: 0.9006 - val_accuracy: 0.6691 - lr: 6.2500e-06 - 934s/epoch - 157ms/step
# Epoch 71/200
# 5964/5964 - 939s - loss: 0.7794 - accuracy: 0.7097 - val_loss: 0.9020 - val_accuracy: 0.6685 - lr: 6.2500e-06 - 939s/epoch - 157ms/step
# Epoch 72/200
# 5964/5964 - 932s - loss: 0.7816 - accuracy: 0.7085 - val_loss: 0.9010 - val_accuracy: 0.6692 - lr: 6.2500e-06 - 932s/epoch - 156ms/step
# Epoch 73/200
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 5964/5964 - 934s - loss: 0.7800 - accuracy: 0.7100 - val_loss: 0.9006 - val_accuracy: 0.6687 - lr: 6.2500e-06 - 934s/epoch - 157ms/step
# end

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\cwt_all_std_force_quality\Conv2D_transfer_ResNet.h5', save_format="h5")

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict(val_generator)
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    df_val["case"],
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN2D_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 169s 113ms/step

# %%
_, accuracy = model.evaluate(val_generator)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 172s 115ms/step - loss: 0.8986 - accuracy: 0.6689
# Test accuracy: 66.89%
